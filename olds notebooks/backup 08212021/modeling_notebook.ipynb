# %% [markdown]
# <div style="display: flex; background-color: #3F579F;">
#     <h1 style="margin: auto; font-weight: bold; padding: 30px 30px 0px 30px;" align="center">Consumption needs of buildings - P4</h1>
# </div>
# <div style="display: flex; background-color: #3F579F; margin: auto; padding: 5px 30px 0px 30px;" >
#     <center style="width: 100%; text-align: center; float: left; font-size: 24px;">| Modeling notebook XXX |</center>
# </div>
# <div style="display: flex; background-color: #3F579F; margin: auto; padding: 10px 30px 30px 30px;">
#     <span style="width: 100%; text-align: center; float: left; font-size: 24px;" align="center">Data Scientist course - OpenClassrooms</span>
# </div>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">1. Libraries and functions</h2>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">1.1. Libraries and functions</h3>
# </div>

# %%
## df_analysis
import io
import gc
import timeit
import math
from math import prod

## General
import pandas as pd
import numpy as np
from numpy.random import seed, randint
import matplotlib.pyplot as plt
import seaborn as sns

## Scikit Learn library
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.inspection import permutation_importance
from sklearn.model_selection import cross_validate, KFold, GridSearchCV, validation_curve, learning_curve, cross_val_predict, cross_val_predict
from sklearn.neighbors import KNeighborsRegressor, NearestNeighbors
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR


# %matplotlib inline

sns.set_theme(style="darkgrid")

SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
SUP = str.maketrans("0123456789", "⁰¹²³⁴⁵⁶⁷⁸⁹")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">1.2. Functions declaration</h3>
# </div>

# %%
def df_analysis(df, name_df, *args, **kwargs):
    """
    Method used to analyze on the DataFrame.

    Parameters:
    -----------------
        df : pandas.DataFrame
        Dataset to analyze.
        
        name_df : str
        Dataset name.
        
        *args, **kwargs:
        -----------------
            columns : list
            Dataframe keys in list format.
            
            flag : str
            Flag to show complete information about the dataset to analyse
            "complete" shows all information about the dataset.

    Returns:
    -----------------
        None. 
        Print the analysis on the Dataset. 
        
    """
    
    # Getting the variables
    columns = kwargs.get("columns", None)
    type_analysis = kwargs.get("type_analysis", None)
    
    ORDERING_COMPLETE = [
        "name", "type", "records", "unique", "# NaN", "% NaN", "mean", "min", "25%", "50%", "75%", "max", "std"
    ]
    
    # Calculating the memory usage based on dataframe.info()
    buf = io.StringIO()
    df.info(buf=buf)
    memory_usage = buf.getvalue().split('\n')[-2]
    
    if df.empty:
        print("The", name_df, "dataset is empty. Please verify the file.")
    else:
        empty_cols = [col for col in df.columns if df[col].isna().all()] # identifying empty columns
        df_rows_duplicates = df[df.duplicated()] #identifying full duplicates rows
        
        # Creating a dataset based on Type object and records by columns
        type_cols = df.dtypes.apply(lambda x: x.name).to_dict() 
        df_resume = pd.DataFrame(list(type_cols.items()), columns = ["name", "type"])
        df_resume["records"] = list(df.count())
        df_resume["# NaN"] = list(df.isnull().sum())
        df_resume["% NaN"] = list(((df.isnull().sum() / len(df.index))*100).round(2))
        
        print("\nAnalysis of", name_df, "dataset")
        print("--------------------------------------------------------------------")
        print("- Dataset shape:                 ", df.shape[0], "rows and", df.shape[1], "columns")
        print("- Total of NaN values:           ", df.isna().sum().sum())
        print("- Percentage of NaN:             ", round((df.isna().sum().sum() / prod(df.shape)) * 100, 2), "%")
        print("- Total of full duplicates rows: ", df_rows_duplicates.shape[0])
        print("- Total of empty rows:           ", df.shape[0] - df.dropna(axis="rows", how="all").shape[0]) if df.dropna(axis="rows", how="all").shape[0] < df.shape[0] else \
                    print("- Total of empty rows:            0")
        print("- Total of empty columns:        ", len(empty_cols))
        print("  + The empty column is:         ", empty_cols) if len(empty_cols) == 1 else \
                    print("  + The empty column are:         ", empty_cols) if len(empty_cols) >= 1 else None
        print("- Unique indexes:                ", df.index.is_unique)
        
        if columns is not None:
            print("\n- The key(s):", columns, "is not present multiple times in the dataframe.\n  It CAN be used as a primary key.") if df.size == df.drop_duplicates(columns).size else \
                print("\n- The key(s):", columns, "is present multiple times in the dataframe.\n  It CANNOT be used as a primary key.")
        
        if type_analysis == "summarized":
            print("\n")
        
        if type_analysis is None or type_analysis != "summarized":
            pd.set_option("display.max_rows", None) # show full of showing rows
            pd.set_option("display.max_columns", None) # show full of showing cols
            pd.set_option("display.max_colwidth", None) # show full width of showing cols
            pd.set_option("display.float_format", lambda x: "%.5f" % x) # show full content in cell    
            
            if type_analysis is None or type_analysis != "complete":
                print("\n- Type object and records by columns      (",memory_usage,")")
                print("--------------------------------------------------------------------")
            elif type_analysis == "complete":
                df_resume["unique"] = list(df.nunique())
                df_desc = pd.DataFrame(df.describe().T).reset_index()
                df_desc = df_desc.rename(columns={"index": "name"})
                df_resume = df_resume.merge(right=df_desc[["name", "mean", "min", "25%", "50%", "75%", "max", "std"]], on="name", how="left")
                df_resume = df_resume[ORDERING_COMPLETE]
                print("\n- Type object and records by columns      (",memory_usage,")")
                print("--------------------------------------------------------------------")
                
            display(df_resume.sort_values("records", ascending=False))
            
            pd.reset_option("display.max_rows") # reset max of showing rows
            pd.reset_option("display.max_columns") # reset max of showing cols
            pd.reset_option("display.max_colwidth") # reset width of showing cols
            pd.reset_option("display.float_format") # reset show full content in cell
            
        # deleting dataframe to free memory
        if type_analysis == "complete":
            del [[df_resume, df_desc]]
            gc.collect()
            df_resume, df_desc = (pd.DataFrame() for i in range(2))
        else:
            del df_resume
            gc.collect()
            df_resume = pd.DataFrame()


def plot_validation_curve(estimator, name_model, X_train, y_train, param_name, param_range, param_name_short, scoring=None, cv=None):
    """
    Generate 1 plots: 
        1. The test and training validation curve
    
    Parameters
    -----------------
    estimator : estimator instance
        An estimator instance implementing `fit` and `predict` methods which
        will be cloned for each validation.
        
    name_model : str
        Name of the model as title for the chart.     
        
    X_train : array-like of shape (n_samples, n_features)
        Training vector, where ``n_samples`` is the number of samples and
        ``n_features`` is the number of features.

    y_train : array-like of shape (n_samples) or (n_samples, n_features)
        Target relative to ``X`` for classification or regression;
        None for unsupervised learning.      
        
    param_name : str
        Name of the parameter that will be varied.
    
    param_range : array-like of shape (n_values,)
        The values of the parameter that will be evaluated.
    
    param_name_short : str
        Short name for param_name
        
    cv : int, cross-validation generator or an iterable, default=None
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:

          - None, to use the default 5-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.
        
    Returns:
    -----------------
        None. 
        Plot the graph. 
        
    """    
    # Initializing figure
    fig = plt.figure(figsize=(8, 6))
    
    if name_model in ["LinearRegression", "LinearRegression - Polynomial", "KNeighbors", "Lasso", "SVR", "RandomForestRegressor"]:
        
        # Get the validation_curves results
        train_scores, test_scores = validation_curve(estimator, X_train, y_train, param_name=param_name, param_range=param_range, cv=kfold)

        train_scores_mean = np.mean(train_scores, axis=1)
        train_scores_std = np.std(train_scores, axis=1)
        test_scores_mean = np.mean(test_scores, axis=1)
        test_scores_std = np.std(test_scores, axis=1)

        plot = sns.lineplot(x=param_range, y=train_scores_mean, label="Train", marker="o")
        plt.fill_between(param_range, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="blue")

        plot = sns.lineplot(x=param_range, y=test_scores_mean, label="Validation", marker="o")
        plt.fill_between(param_range, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="orange")

        plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)
        plt.title(name_model + " Validation curve", fontdict={ "fontsize": 16, "fontweight": "normal" })
        plot.set(xlabel=param_name_short, ylabel="R2-score".translate(SUP), xlim=[0, max(param_range)])
        
    elif name_model == "GradientBoostingRegressor":
    
       # Get the validation_curves results
        train_scores, test_scores = validation_curve(estimator, X_train, y_train, param_name=param_name, param_range=param_range, scoring=scoring, cv=kfold)
        
        train_errors, test_errors = -train_scores, -test_scores
        
        plt.errorbar(param_range, train_errors.mean(axis=1), yerr=train_errors.std(axis=1), label="Training score")
        plt.errorbar(param_range, test_errors.mean(axis=1), yerr=test_errors.std(axis=1), label="Cross-validation score")

        plt.legend()
        
        # Mean absolute error in k$\n(smaller is better)
        plt.ylabel("MAE")
        plt.xlabel("Estimators")
        _ = plt.title(name_model + " Validation curve", fontdict={ "fontsize": 16, "fontweight": "normal" })
        
    plt.savefig("img/" + name_model + "-validation-curve.png")
    sns.despine(fig)
    plt.show()

            
def plot_learning_curve(estimator, name_model, X_train, y_train, cv=None, train_sizes=np.linspace(0.2, 1.0, 10)):
    """
    Generate 3 plots: 
        1. The test and training learning curve
        2. The training samples vs fit times curve
        3. The fit times vs score curve
    
    Parameters
    -----------------
    estimator : estimator instance
        An estimator instance implementing `fit` and `predict` methods which
        will be cloned for each validation.
        
    name_model : str
        Name of the model as title for the chart.        
        
    X_train : array-like of shape (n_samples, n_features)
        Training vector, where ``n_samples`` is the number of samples and
        ``n_features`` is the number of features.

    y_train : array-like of shape (n_samples) or (n_samples, n_features)
        Target relative to ``X`` for classification or regression;
        None for unsupervised learning.        
        
    cv : int, cross-validation generator or an iterable, default=None
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:

          - None, to use the default 5-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    train_sizes : array-like of shape (n_ticks,)
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the ``dtype`` is float, it is regarded
        as a fraction of the maximum size of the training set (that is
        determined by the selected validation method), i.e. it has to be within
        (0, 1]. Otherwise it is interpreted as absolute sizes of the training
        sets. Note that for classification the number of samples usually have
        to be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5) or (0.2, 1.0, 10))
        
    Returns:
    -----------------
        None. 
        Plot the graphs. 
        
    """
    
    # Get the learning_curves results
    train_sizes, train_scores, test_scores, fit_times, _ = learning_curve(estimator, X_train, y_train, cv=cv, \
                                                                           train_sizes=train_sizes, n_jobs=-1, return_times=True)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)
    
    # Initializing figure
    fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(24, 6))
    
    # Plot learning curve
    plot = sns.lineplot(x=train_sizes, y=train_scores_mean, label="Train", marker="o", ax=ax1)
    ax1.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="blue")

    plot = sns.lineplot(x=train_sizes, y=test_scores_mean, label="Validation", marker="o", ax=ax1)
    ax1.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="orange")
    
    ax1.legend(loc="best")
    ax1.set_title(" Learning curve (" + name_model + ")", fontdict={ "fontsize": 16, "fontweight": "normal" })
    plot.set(xlabel="Training examples", ylabel="R2-score".translate(SUP))
    
    # Plot Scalability of the model
    plot = sns.lineplot(x=train_sizes, y=fit_times_mean, marker="o", ax=ax2)
    ax2.fill_between(train_sizes, fit_times_mean - fit_times_std, fit_times_mean + fit_times_std, alpha=0.1, color="blue")
    
    ax2.set_title("Scalability of the model", fontdict={ "fontsize": 16, "fontweight": "normal" })
    plot.set(xlabel="Training examples", ylabel="Fit times")

    # Performance of the model
    plot = sns.lineplot(x=fit_times_mean, y=test_scores_mean, marker="o", ax=ax3)
    ax3.fill_between(fit_times_mean, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1)
    
    ax3.set_title("Performance of the model", fontdict={ "fontsize": 16, "fontweight": "normal" })
    plot.set(xlabel="Fit times examples", ylabel="R2-score".translate(SUP))
    
    plt.savefig("img/" + name_model + "-performance-model.png")
    sns.despine(fig)
    plt.show()


def plot_cross_val_predi(estimator, name_model, target_variable, X_train, y_train, cv=None):
    """
    Generate 1 plots: 
        1. The validation between real values vs predicted values
    
    Parameters
    -----------------
    estimator : estimator instance
        An estimator instance implementing `fit` and `predict` methods which
        will be cloned for each validation.
        
    name_model : str
        Name of the model as title for the chart.   

    target_variable : str
        Name of the target variable.    
        
    X_train : array-like of shape (n_samples, n_features)
        Training vector, where ``n_samples`` is the number of samples and
        ``n_features`` is the number of features.

    y_train : array-like of shape (n_samples) or (n_samples, n_features)
        Target relative to ``X`` for classification or regression;
        None for unsupervised learning.      
        
    cv : int, cross-validation generator or an iterable, default=None
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:

          - None, to use the default 5-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.
        
    Returns:
    -----------------
        None. 
        Plot the graph. 
        
    """   
    
    # Get the predicted values
    predicted = cross_val_predict(estimator, X_train, y_train, cv=kfold)
    
    # Initializing figure
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 8))
    
    # Main title
    plt.suptitle("Real values vs Predicted values", size=24)
    
    ax1.scatter(y_train, predicted, edgecolors=(0, 0, 0))
    ax1.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], "--k", lw=4)
    
    ax1.text(min(y_train)+0.2, 0.98*max(y_train), r'$R^2$=%.2f, RMSE=%.2f' % (
            round(r2_score(y_train, predicted), 3),
            round(math.sqrt(mean_squared_error(y_train, predicted)), 3)), 
            style="italic", fontsize=12,
            bbox={"facecolor": "grey", "alpha": 0.4, "pad": 5})
    
    sns.kdeplot(y_train, color="r", label="Real values", ax=ax2)
    sns.kdeplot(predicted, color="b", label="Predicted values", ax=ax2)
    
    ax1.set_title(name_model + " Cross-Values Predictions", fontdict={ "fontsize": 16, "fontweight": "normal" })
    ax1.set_xlabel("Real values")
    ax1.set_ylabel("Predicted values")
    
    ax2.set_title("Distribution plot based on density", fontdict={ "fontsize": 16, "fontweight": "normal" })
    ax2.set_xlabel("SiteEnergyUse(kBtu)")
    ax2.set_ylabel("Density")
    plt.legend(bbox_to_anchor=(0.99, 0.99), borderaxespad=0)
    
    plt.savefig("img/" + name_model + "-cross-val-predict.png")
    plt.show()
    

def plot_features_importance(estimator, name_model, X_train, y_train, scoring=None):
    """
    Generate 1 plots: 
        1. The importance by feature
    
    Parameters
    -----------------
    estimator : estimator instance
        An estimator instance implementing `fit` and `predict` methods which
        will be cloned for each validation.
        
    name_model : str
        Name of the model as title for the chart.     
        
    X_train : array-like of shape (n_samples, n_features)
        Training vector, where ``n_samples`` is the number of samples and
        ``n_features`` is the number of features.

    y_train : array-like of shape (n_samples) or (n_samples, n_features)
        Target relative to ``X`` for classification or regression;
        None for unsupervised learning. 
        
    scoring : string, callable or None, default=None
        Scorer to use. It can be a single string or a callable. 
        If None, the estimator’s default scorer is used. 
        
    Returns:
    -----------------
        None. 
        Plot the graph. 
        
    """     
    # Get the importance by feature
    results = permutation_importance(estimator, X_train, y_train, scoring="neg_mean_squared_error")
    
    # Making a dataframe to work easily
    df_importance = pd.DataFrame({
                        "Feature" : X_train.columns,
                        "Importance" : results.importances_mean
                    })
    
    # Sorting by importance before plotting
    df_importance = df_importance.sort_values("Importance")
    
    # Initializing figure    
    fig = plt.subplots(figsize=(10, 8))
    
    plot = sns.barplot(data=df_importance, y=df_importance["Feature"], x=df_importance["Importance"])
    
    plt.title(name_model + " Features Importance", fontdict={ "fontsize": 16, "fontweight": "normal" })
    plt.xlabel("Importance")
    plt.ylabel("Features")
    plt.tight_layout()
    plt.savefig("img/" + name_model + "-feature-importance.png")
    plt.show()

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">2. Importing files</h2>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">2.1. Importing and preparing files</h3>
# </div>

# %%
data = pd.read_csv(r"datasets\df_cleaned.csv")

# %%
data.head()
# Out:
#    NumberofFloors  NumberofBuildings  BuildingAge  PropertyGFAParking  \
# 0            12.0                1.0         94.0                 0.0
# 1            11.0                1.0         25.0             15064.0
# 2            10.0                1.0         95.0                 0.0
# 3            18.0                1.0         41.0             62000.0
# 4            11.0                1.0         95.0                 0.0
#
#    PropertyGFABuilding(s) Neighborhood renamed_PropertyType  \
# 0                 88434.0     DOWNTOWN                Hotel
# 1                 88502.0     DOWNTOWN                Hotel
# 2                 61320.0     DOWNTOWN                Hotel
# 3                113580.0     DOWNTOWN                Hotel
# 4                 83008.0     DOWNTOWN                Hotel
#
#    Electricity_ratio  SiteEnergyUse(kBtu)  GHGEmissions(MetricTonsCO2e)
# 0           52.79951            6981428.0                        249.43
# 1           46.74768            8354235.0                        263.51
# 2            9.80903           28229320.0                       1936.34
# 3           40.90771           14829099.0                        507.70
# 4           42.85568            6252842.0                        208.46

# %%
df_analysis(data, "data", type_analysis="complete")
# Out:
# Analysis of data dataset
# --------------------------------------------------------------------
# - Dataset shape:                  1551 rows and 10 columns
# - Total of NaN values:            0
# - Percentage of NaN:              0.0 %
# - Total of full duplicates rows:  0
# - Total of empty rows:            0
# - Total of empty columns:         0
# - Unique indexes:                 True
#
# - Type object and records by columns      ( memory usage: 121.3+ KB )
# --------------------------------------------------------------------
#                            name     type  records  unique  # NaN   % NaN  \
# 0                NumberofFloors  float64     1551      28      0 0.00000
# 1             NumberofBuildings  float64     1551       4      0 0.00000
# 2                   BuildingAge  float64     1551     113      0 0.00000
# 3            PropertyGFAParking  float64     1551     280      0 0.00000
# 4        PropertyGFABuilding(s)  float64     1551    1469      0 0.00000
# 5                  Neighborhood   object     1551      13      0 0.00000
# 6          renamed_PropertyType   object     1551       8      0 0.00000
# 7             Electricity_ratio  float64     1551    1209      0 0.00000
# 8           SiteEnergyUse(kBtu)  float64     1551    1550      0 0.00000
# 9  GHGEmissions(MetricTonsCO2e)  float64     1551    1481      0 0.00000
#
#            mean         min           25%           50%           75%  \
# 0       3.36944     1.00000       1.00000       2.00000       4.00000
# 1       1.00516     1.00000       1.00000       1.00000       1.00000
# 2      59.89297     6.00000      33.00000      57.00000      91.00000
# 3    8472.80916     0.00000       0.00000       0.00000       0.00000
# 4   75768.87814  3636.00000   27710.00000   45000.00000   82543.00000
# 5           NaN         NaN           NaN           NaN           NaN
# 6           NaN         NaN           NaN           NaN           NaN
# 7      70.57165     0.00033      50.30382      71.44200     100.00101
# 8 5777559.01140 11441.00000 1182991.50000 2316441.00000 6157736.50000
# 9     127.80329     0.08000      18.86500      45.90000     120.12000
#
#               max            std
# 0        33.00000        3.64942
# 1         6.00000        0.13903
# 2       121.00000       32.56694
# 3    206597.00000    25823.59232
# 4   1158691.00000    90312.92302
# 5             NaN            NaN
# 6             NaN            NaN
# 7       100.00874       25.87075
# 8 295812640.00000 13228100.09894
# 9     10780.64000      423.95305

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">3. Splitting data (SiteEnergyUse(kBtu)</h2>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">3.1. Splitting dataset based on the features and targets</h3>
# </div>

# %%
data.head()
# Out:
#    NumberofFloors  NumberofBuildings  BuildingAge  PropertyGFAParking  \
# 0            12.0                1.0         94.0                 0.0
# 1            11.0                1.0         25.0             15064.0
# 2            10.0                1.0         95.0                 0.0
# 3            18.0                1.0         41.0             62000.0
# 4            11.0                1.0         95.0                 0.0
#
#    PropertyGFABuilding(s) Neighborhood renamed_PropertyType  \
# 0                 88434.0     DOWNTOWN                Hotel
# 1                 88502.0     DOWNTOWN                Hotel
# 2                 61320.0     DOWNTOWN                Hotel
# 3                113580.0     DOWNTOWN                Hotel
# 4                 83008.0     DOWNTOWN                Hotel
#
#    Electricity_ratio  SiteEnergyUse(kBtu)  GHGEmissions(MetricTonsCO2e)
# 0           52.79951            6981428.0                        249.43
# 1           46.74768            8354235.0                        263.51
# 2            9.80903           28229320.0                       1936.34
# 3           40.90771           14829099.0                        507.70
# 4           42.85568            6252842.0                        208.46

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Working with a copy
# </div>

# %%
data_trans = data.copy()

# %%
data_trans.head()
# Out:
#    NumberofFloors  NumberofBuildings  BuildingAge  PropertyGFAParking  \
# 0            12.0                1.0         94.0                 0.0
# 1            11.0                1.0         25.0             15064.0
# 2            10.0                1.0         95.0                 0.0
# 3            18.0                1.0         41.0             62000.0
# 4            11.0                1.0         95.0                 0.0
#
#    PropertyGFABuilding(s) Neighborhood renamed_PropertyType  \
# 0                 88434.0     DOWNTOWN                Hotel
# 1                 88502.0     DOWNTOWN                Hotel
# 2                 61320.0     DOWNTOWN                Hotel
# 3                113580.0     DOWNTOWN                Hotel
# 4                 83008.0     DOWNTOWN                Hotel
#
#    Electricity_ratio  SiteEnergyUse(kBtu)  GHGEmissions(MetricTonsCO2e)
# 0           52.79951            6981428.0                        249.43
# 1           46.74768            8354235.0                        263.51
# 2            9.80903           28229320.0                       1936.34
# 3           40.90771           14829099.0                        507.70
# 4           42.85568            6252842.0                        208.46

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Making log transformation on specific columns based on the analysis conclusions done
# </div>

# %%
LOG_TRANS_FEATURES = ["PropertyGFABuilding(s)", "SiteEnergyUse(kBtu)", "GHGEmissions(MetricTonsCO2e)"]

# %%
for col in LOG_TRANS_FEATURES:
    data_trans[col] = np.log2(data_trans[col])

# %%
data_trans.head()
# Out:
#    NumberofFloors  NumberofBuildings  BuildingAge  PropertyGFAParking  \
# 0            12.0                1.0         94.0                 0.0
# 1            11.0                1.0         25.0             15064.0
# 2            10.0                1.0         95.0                 0.0
# 3            18.0                1.0         41.0             62000.0
# 4            11.0                1.0         95.0                 0.0
#
#    PropertyGFABuilding(s) Neighborhood renamed_PropertyType  \
# 0               16.432314     DOWNTOWN                Hotel
# 1               16.433422     DOWNTOWN                Hotel
# 2               15.904070     DOWNTOWN                Hotel
# 3               16.793349     DOWNTOWN                Hotel
# 4               16.340963     DOWNTOWN                Hotel
#
#    Electricity_ratio  SiteEnergyUse(kBtu)  GHGEmissions(MetricTonsCO2e)
# 0           52.79951            22.735091                      7.962491
# 1           46.74768            22.994076                      8.041714
# 2            9.80903            24.750691                     10.919117
# 3           40.90771            23.821928                      8.987832
# 4           42.85568            22.576081                      7.703627

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Splitting dataset based on the features and targets
# </div>

# %%
X = data_trans.drop(columns=["SiteEnergyUse(kBtu)", "GHGEmissions(MetricTonsCO2e)"])

# %%
y_energy = data_trans.iloc[:,-2]

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">3.2. Train/Test split</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     At this point, we are going to predict <b>SiteEnergyUse(kBtu)</b>
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_energy, test_size=0.3, random_state=0)

# %%
print("X_train: {}".format(X_train.shape))
print("y_train: {}".format(y_train.shape))
# Out:
# X_train: (1085, 8)
# y_train: (1085,)

# %%
X_train.head()
# Out:
#       NumberofFloors  NumberofBuildings  BuildingAge  PropertyGFAParking  \
# 649              3.0                1.0          6.0                 0.0
# 1300             1.0                1.0         76.0                 0.0
# 1392             1.0                1.0         71.0                 0.0
# 1214             1.0                1.0         52.0                 0.0
# 1239             1.0                1.0         49.0                 0.0
#
#       PropertyGFABuilding(s)      Neighborhood renamed_PropertyType  \
# 649                15.457637  GREATER DUWAMISH            Education
# 1300               14.487589  GREATER DUWAMISH            Warehouse
# 1392               14.339015  GREATER DUWAMISH            Warehouse
# 1214               15.188859  GREATER DUWAMISH            Warehouse
# 1239               15.554109         NORTHWEST            Warehouse
#
#       Electricity_ratio
# 649           100.00002
# 1300          100.00400
# 1392           16.56582
# 1214           53.42718
# 1239          100.00417

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">3.3. Identifying types of features</h3>
# </div>

# %%
NUMERICAL_FEATURES = ["NumberofFloors", "NumberofBuildings", "BuildingAge", "PropertyGFAParking", "PropertyGFABuilding(s)", "Electricity_ratio"]
CATEGORICAL_FEATURES = ["Neighborhood", "renamed_PropertyType"]

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">4. Data preprocessing</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#      We are going to process the features as follows<br><br>
#     <b>Numerical features</b>
#     <ul style="list-style-type: square;">
#         <li>Normalizing the features through StandardScaler due to all of them do not have a normal distribution</li>
#     </ul>
#     <b>Categorical features</b>
#     <ul style="list-style-type: square;">
#         <li>Transforming all features through LabelEncoder</li>
#     </ul>
# </div>

# %%
numerical_pipeline = make_pipeline(StandardScaler())

categorical_pipeline = make_pipeline(OneHotEncoder())

# %%
preprocessor = make_column_transformer(
                (numerical_pipeline, NUMERICAL_FEATURES), 
                (categorical_pipeline, CATEGORICAL_FEATURES))

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">5. Modelisation</h2>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">5.1. Supervised models</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     List of models to use. for now, in default mode
# </div>

# %%
regressors = {
    "Linear" : LinearRegression(),
    "KNeighbors" : KNeighborsRegressor(n_neighbors=2),
    "Lasso" : Lasso(),
    "SVR" : SVR(),
    "Random Forest" : RandomForestRegressor(),
    "Gradient Boosting" : GradientBoostingRegressor()
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Models metrics
# </div>

# %%
# Dataframe with y_test_transformed to compared againts predictions
df_y_pred = pd.DataFrame({
        "Model" : "Original",
        "y_pred" : y_test
})

# List of metrics results for each models 
LIST_MODEL, LIST_R2SCORE, LIST_MAE, LIST_RMSE, LIST_DURATION  = ([] for i in range(5))

for k, v in regressors.items():
    
    start_time_model = timeit.default_timer()
    
    # Data preprocessing based on the pipelines and the regressors setup
    reg = make_pipeline(preprocessor, v)
    
    # Fit the model using the training data and training target
    reg.fit(X_train, y_train)
    
    # Making the prediction using the testing data
    y_pred = reg.predict(X_test)
    
    end_time_model =  round(timeit.default_timer() - start_time_model, 3)
    
    # Concatenating predictions to compare against y_test_transformed
    df_temp = pd.DataFrame({
        "Model" : k,
        "y_pred" : y_pred
    })
    
    # Concatenating predictions to compare against y_test_transformed
    df_y_pred = pd.concat([df_y_pred, df_temp])
    
    # Calculating R2 Coefficient of determination for each model (Best possible score is 1.0, lower values are worse.)
    R2SCORE = round(1 - r2_score(y_test, y_pred), 3)
    
    # Calculating the Mean absolute error (The best value is 0.0)
    MAE = round(mean_absolute_error(y_test, y_pred), 3)
    
    # Calculating Root Mean Square Error for each model (The best value is 0.0)
    RMSE = round(mean_squared_error(y_test, y_pred, squared=False), 3)
    
    # Adding results into LIST
    LIST_MODEL.append(k)
    LIST_R2SCORE.append(R2SCORE)
    LIST_MAE.append(MAE)
    LIST_RMSE.append(RMSE)
    LIST_DURATION.append(end_time_model)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Comparison of energy predictions against original data
# </div>

# %%
plt.figure(figsize=[10,6])
sns.boxplot(x=df_y_pred["Model"], y=df_y_pred["y_pred"], showmeans=True, 
            meanprops={"markerfacecolor":"white", "markeredgecolor":"blue"})
plt.title("Comparison of energy predictions (default mode)", size=16)
plt.xlabel("Original target and targets predicted", size=12)
plt.tight_layout()
plt.savefig("img/Comparison-of-imputations.png")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#
#     <p>At this point, we can see that <b>Kneighbors</b>, <b>Random Forest</b> and <b>Gradient Boosting</b> are the most <b>similar to Original data</b></p>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">5.2. Predictions metrics</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Creating dataframe based on metrics results for each models
# </div>

# %%
df_models_metrics = pd.DataFrame({
    "Model" : LIST_MODEL,
    "R2".translate(SUP) : LIST_R2SCORE, 
    "MAE" : LIST_MAE,    
    "RMSE" : LIST_RMSE,
    "Duration" : LIST_DURATION,
})

df_models_metrics
# Out:
#                Model     R²    MAE   RMSE  Duration
# 0             Linear  0.584  0.840  1.100     0.065
# 1         KNeighbors  0.416  0.990  1.304     0.074
# 2              Lasso  0.176  1.218  1.548     0.035
# 3                SVR  0.612  0.794  1.062     0.196
# 4      Random Forest  0.605  0.812  1.072     2.437
# 5  Gradient Boosting  0.638  0.782  1.026     0.292

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#
#     <b>Best results</b> with default mode considering each model
#     <ul style="list-style-type: square;">
#         <li><b>r2:</b> Gradient Boosting(0.639) </li>
#         <li><b>MAE:</b> Gradient Boosting(0.778) </li>
#         <li><b>RMSE:</b> Gradient Boosting(1.025) </li>
#         <li><b>Duration:</b> Lasso(0.186) </li>
#     </ul>
# </div>

# %%
df_models_metrics_melt = pd.melt(df_models_metrics, id_vars="Model", var_name="Metric", value_name="Value")
df_models_metrics_melt.head(8)
# Out:
#                Model Metric  Value
# 0             Linear     R²  0.584
# 1         KNeighbors     R²  0.416
# 2              Lasso     R²  0.176
# 3                SVR     R²  0.612
# 4      Random Forest     R²  0.605
# 5  Gradient Boosting     R²  0.638
# 6             Linear    MAE  0.840
# 7         KNeighbors    MAE  0.990

# %%
fig, ax1 = plt.subplots(figsize=(15, 6))
plot = sns.barplot(x="Model", y="Value", hue="Metric", data=df_models_metrics_melt, ax=ax1)
for p in plot.patches:
    plot.annotate(format(p.get_height(), ".2f"), (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha="center", va="center", xytext=(0, 8), textcoords="offset points")
plt.title("Comparison of Metrics by model (default mode)", size=20)
plt.legend(bbox_to_anchor=(1.10, 1), borderaxespad=0, title="Metrics")
plt.tight_layout()
plt.xlabel("Model", size=12)
plt.ylabel("Metric", size=12)
plt.savefig("img/comparisonMetricsByModel.png")
sns.despine(fig)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#
#     So far, <b>Gradient Boosting</b> is giving the best result with <b>default parameters</b>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">5.3. Cross Validation K-Fold</h3>
# </div>

# %%
# List of metrics results for each models 
LIST_MODEL, LIST_R2SCORE, LIST_MAE, LIST_RMSE, LIST_DURATION, LIST_SCORES  = ([] for i in range(6))

for k, v in regressors.items():

    # Data preprocessing based on the pipelines and the regressors setup
    reg = make_pipeline(preprocessor, v)
    
    kfold = KFold(n_splits=5, shuffle=False, random_state=None)
    
    # Get the score for each validation score method to get accuracy of model
    scores = cross_validate(reg, X_train, y_train, cv=kfold, scoring=("r2", "neg_mean_absolute_error", "neg_mean_squared_error"), return_train_score=True)
    
    # Adding results into LIST
    LIST_MODEL.append(k)
    LIST_R2SCORE.append(round(scores.get("test_r2").mean(), 3))
    LIST_MAE.append(round(abs(scores.get("test_neg_mean_absolute_error").mean()), 3))
    LIST_RMSE.append(round(math.sqrt((abs(scores.get("test_neg_mean_squared_error").mean()))), 3))
    LIST_DURATION.append(round(scores.get("fit_time").mean(), 3))
    LIST_SCORES.append(scores.get("test_r2"))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting the cross validation executions
# </div>

# %%
df_cross_val = pd.DataFrame(LIST_SCORES, columns=[1, 2, 3, 4, 5])
df_cross_val["Model"] = LIST_MODEL
df_cross_val_melt = df_cross_val.melt(id_vars="Model", var_name="Execution", value_name="Score")

# %%
df_cross_val
# Out:
#           1         2         3         4         5              Model
# 0  0.637887  0.618943  0.638783  0.610068  0.631712             Linear
# 1  0.424300  0.503938  0.503281  0.371916  0.493936         KNeighbors
# 2  0.191927  0.169527  0.190145  0.152504  0.185527              Lasso
# 3  0.656038  0.625821  0.684525  0.634142  0.626455                SVR
# 4  0.663438  0.645891  0.665360  0.670210  0.651834      Random Forest
# 5  0.663468  0.671380  0.680991  0.670091  0.658762  Gradient Boosting

# %%
plt.figure(figsize=(8, 6))
plot = sns.lineplot(x="Execution",
                    y="Score",
                    hue="Model",
                    data=df_cross_val_melt
)
plt.legend(bbox_to_anchor=(0.85, 1), borderaxespad=0, title="Model")
plt.tight_layout()
plt.title("Models cross validations", size=20)
plot.set(xlabel="Execution", ylabel="Score", xlim=(1, 6))

plt.savefig("img/models-cross-validations-Scores.png")
sns.despine(fig)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#
#     At this point, we can see
#     <ul style="list-style-type: square;">
#         <li><b>Gradient Boosting</b> is the best result </li>
#         <li><b>Lasso</b> is the worst result </li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">5.3.1 Predictions metrics</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Creating dataframe based on metrics results for each models
# </div>

# %%
df_models_metrics_cross = pd.DataFrame({
    "Model" : LIST_MODEL,
    "R2".translate(SUP) : LIST_R2SCORE, 
    "MAE" : LIST_MAE,    
    "RMSE" : LIST_RMSE,
    "Duration" : LIST_DURATION,
})

df_models_metrics_cross
# Out:
#                Model     R²    MAE   RMSE  Duration
# 0             Linear  0.627  0.804  1.091     0.027
# 1         KNeighbors  0.459  0.943  1.317     0.015
# 2              Lasso  0.178  1.260  1.620     0.019
# 3                SVR  0.645  0.766  1.066     0.090
# 4      Random Forest  0.659  0.748  1.041     1.551
# 5  Gradient Boosting  0.669  0.752  1.027     0.301

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Best results</b> with default mode considering each model
#     <ul style="list-style-type: square;">
#         <li><b>r2:</b> Gradient Boosting(0.701) </li>
#         <li><b>MAE:</b> Gradient Boosting(0.777) </li>
#         <li><b>RMSE:</b> Gradient Boosting(1.054) </li>
#         <li><b>Duration:</b> Lasso(0.008) </li>
#     </ul>
# </div>

# %%
df_models_metrics_melt_cross = pd.melt(df_models_metrics_cross, id_vars="Model", var_name="Metric", value_name="Value")
df_models_metrics_melt_cross.head()
# Out:
#            Model Metric  Value
# 0         Linear     R²  0.627
# 1     KNeighbors     R²  0.459
# 2          Lasso     R²  0.178
# 3            SVR     R²  0.645
# 4  Random Forest     R²  0.659

# %%
fig, ax1 = plt.subplots(figsize=(15, 6))
plot = sns.barplot(x="Model", y="Value", hue="Metric", data=df_models_metrics_melt_cross, ax=ax1)
for p in plot.patches:
    plot.annotate(format(p.get_height(), ".2f"), (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha="center", va="center", xytext=(0, 8), textcoords="offset points")
plt.title("Comparison of Metrics by model (cross-validation)", size=20)
plt.legend(bbox_to_anchor=(1.10, 1), borderaxespad=0, title="Metrics")
plt.tight_layout()
plt.xlabel("Model", size=12)
plt.ylabel("Metric", size=12)
plt.savefig("img/comparisonMetrics_crossByModel.png")
sns.despine(fig)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#     <ul style="list-style-type: square;">
#         <li>All models are improved their results but, despite that, results are very similar to previous ones</li>
#         <li><b>Gradient Boosting</b> is still giving the best result with <b>default parameters</b> and <b>cross-validation</b></li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">6. Optimization</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We are going to optimize each model separately, to see the results more in detail<br><br>
#
#     Also, we are going to add all predictions and metrics base on parameters optimization to compare the results
# </div>

# %%
# Dataframe with y_test_transformed to compared againts predictions
df_y_pred_gsc = pd.DataFrame({
        "Model" : "Original",
        "y_pred" : y_test
})

# Dataframe for metrics to compare
df_models_metrics_gsc = pd.DataFrame({})

# List of metrics results for each models 
LIST_MODEL_GSC, LIST_R2SCORE_GSC, LIST_MAE_GSC, LIST_RMSE_GSC, LIST_DURATION_GSC, LIST_SCORES_GSC  = ([] for i in range(6))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     At the same time, we are going to get the following metrics
# </div>

# %%
SCORINGS = {
    "R2" : "r2",
    "MSE" : "neg_mean_squared_error", 
    "MAE" : "neg_mean_absolute_error"
}

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">6.1. Linear Regression optimization</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>It is necessary to take in account that we are treating with <b>Non-linear Dataset</b> based on EDA done</p>
#
#     <p>Initializing model</p>
# </div>

# %%
lr = LinearRegression()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Data preprocessing based on the pipelines and the regressors setup
# </div>

# %%
reg = make_pipeline(preprocessor, lr)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Identifying the names of each parameter
# </div>

# %%
sorted(reg.get_params().keys())
# Out:
# ['columntransformer',
#  'columntransformer__n_jobs',
#  'columntransformer__pipeline-1',
#  'columntransformer__pipeline-1__memory',
#  'columntransformer__pipeline-1__standardscaler',
#  'columntransformer__pipeline-1__standardscaler__copy',
#  'columntransformer__pipeline-1__standardscaler__with_mean',
#  'columntransformer__pipeline-1__standardscaler__with_std',
#  'columntransformer__pipeline-1__steps',
#  'columntransformer__pipeline-1__verbose',
#  'columntransformer__pipeline-2',
#  'columntransformer__pipeline-2__memory',
#  'columntransformer__pipeline-2__onehotencoder',
#  'columntransformer__pipeline-2__onehotencoder__categories',
#  'columntransformer__pipeline-2__onehotencoder__drop',
#  'columntransformer__pipeline-2__onehotencoder__dtype',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown',
#  'columntransformer__pipeline-2__onehotencoder__sparse',
#  'columntransformer__pipeline-2__steps',
#  'columntransformer__pipeline-2__verbose',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'linearregression',
#  'linearregression__copy_X',
#  'linearregression__fit_intercept',
#  'linearregression__n_jobs',
#  'linearregression__normalize',
#  'memory',
#  'steps',
#  'verbose']

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Parameters settings
# </div>

# %%
param_grid = {
    "linearregression__copy_X" : [True, False], # If True, X will be copied; else, it may be overwritten.
    "linearregression__fit_intercept" : [True, False] # Whether to calculate the intercept for this model. 
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Executing the model
# </div>

# %%
# K-Folds cross-validator
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

search = GridSearchCV(reg, param_grid, n_jobs=1, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True)

search.fit(X_train, y_train)

# Transforming the result to dataframe format
df_results = pd.DataFrame(search.cv_results_)

# Get the results
print("Metrics based on the best R2".translate(SUP))
print("- R2:".translate(SUP), round(search.best_score_, 3))
print("- MAE:", round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
print("- RMSE:", round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
print("- Duration:", round(df_results.iloc[search.best_index_]["mean_score_time"], 3))
print("- Parameters:", search.best_params_)
# Out:
# Metrics based on the best R²
# - R²: 0.625
# - MAE: 0.801
# - RMSE: 1.093
# - Duration: 0.008
# - Parameters: {'linearregression__copy_X': True, 'linearregression__fit_intercept': False}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We got the <b>best parameters</b> so, we are going to <b>analyze</b> them more in details
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.1.1. Linear Regression Learning curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Learning curve</b>, we are going to use the <b>best  parameters</b> to analyze the model
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

reg = make_pipeline(preprocessor, LinearRegression(copy_X=True, fit_intercept=False))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the learning curve</b> based on the best parameters
# </div>

# %%
plot_learning_curve(reg, "LinearRegression", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.1.2. Linear Regression predictions validations</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>predictions validations</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> and <b>predicting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, LinearRegression(copy_X=True, fit_intercept=False))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Cross-Validated Predictions</b> based on the best parameters for <b>training data</b>
# </div>

# %%
# Making the prediction using the testing data
plot_cross_val_predi(reg, "LinearRegresion", "SiteEnergyUse(kBtu)", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.1.3. Linear Regression Features Importance</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Features Importance</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> values</b>
# </div>

# %%
reg = make_pipeline(preprocessor, LinearRegression(copy_X=True, fit_intercept=False))

reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['NumberofFloors',
#                                                    'NumberofBuildings',
#                                                    'BuildingAge',
#                                                    'PropertyGFAParking',
#                                                    'PropertyGFABuilding(s)',
#                                                    'Electricity_ratio']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Neighborhood',
#                                                    'renamed_PropertyType'])])),
#                 ('linearregression', LinearRegression(fit_intercept=False))])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Features Importance</b> based on the best parameters
# </div>

# %%
plot_features_importance(reg, "LinearRegresion", X_train, y_train, scoring="neg_mean_squared_error")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.1.4. Polynomial Features</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>we are going to work with a <b>Polynomial Features</b> to make a model more complex</p>
#
#     <p>Initializing model</p>
# </div>

# %%
poly = PolynomialFeatures()

lr = LinearRegression()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Data preprocessing based on the pipelines and the regressors setup
# </div>

# %%
poly_reg = make_pipeline(preprocessor, poly, lr)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Identifying the names of each parameter
# </div>

# %%
sorted(poly_reg.get_params().keys())
# Out:
# ['columntransformer',
#  'columntransformer__n_jobs',
#  'columntransformer__pipeline-1',
#  'columntransformer__pipeline-1__memory',
#  'columntransformer__pipeline-1__standardscaler',
#  'columntransformer__pipeline-1__standardscaler__copy',
#  'columntransformer__pipeline-1__standardscaler__with_mean',
#  'columntransformer__pipeline-1__standardscaler__with_std',
#  'columntransformer__pipeline-1__steps',
#  'columntransformer__pipeline-1__verbose',
#  'columntransformer__pipeline-2',
#  'columntransformer__pipeline-2__memory',
#  'columntransformer__pipeline-2__onehotencoder',
#  'columntransformer__pipeline-2__onehotencoder__categories',
#  'columntransformer__pipeline-2__onehotencoder__drop',
#  'columntransformer__pipeline-2__onehotencoder__dtype',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown',
#  'columntransformer__pipeline-2__onehotencoder__sparse',
#  'columntransformer__pipeline-2__steps',
#  'columntransformer__pipeline-2__verbose',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'linearregression',
#  'linearregression__copy_X',
#  'linearregression__fit_intercept',
#  'linearregression__n_jobs',
#  'linearregression__normalize',
#  'memory',
#  'polynomialfeatures',
#  'polynomialfeatures__degree',
#  'polynomialfeatures__include_bias',
#  'polynomialfeatures__interaction_only',
#  'polynomialfeatures__order',
#  'steps',
#  'verbose']

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Parameters settings
# </div>

# %%
param_grid = {
    "polynomialfeatures__degree" : [1, 2, 3, 4],
#     "linearregression__copy_X" : [True, False],
    "linearregression__fit_intercept" : [True, False]
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Executing the model
# </div>

# %%
# K-Folds cross-validator
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

search = GridSearchCV(poly_reg, param_grid, n_jobs=1, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True, verbose=3)

search.fit(X_train, y_train)

# Transforming the result to dataframe format
df_results = pd.DataFrame(search.cv_results_)

# Get the results
print("Metrics based on the best R2".translate(SUP))
print("- R2:".translate(SUP), round(search.best_score_, 3))
print("- MAE:", round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
print("- RMSE:", round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
print("- Duration:", round(df_results.iloc[search.best_index_]["mean_score_time"], 3))
print("- Parameters:", search.best_params_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=1, MAE=(train=-0.749, test=-0.891), MSE=(train=-1.040, test=-1.539), R2=(train=0.667, test=0.556), total=   0.0s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=1, MAE=(train=-0.782, test=-0.802), MSE=(train=-1.130, test=-1.188), R2=(train=0.647, test=0.620), total=   0.0s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=1, MAE=(train=-0.796, test=-0.738), MSE=(train=-1.172, test=-0.982), R2=(train=0.632, test=0.697), total=   0.0s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=1, MAE=(train=-0.772, test=-0.818), MSE=(train=-1.086, test=-1.336), R2=(train=0.660, test=0.579), total=   0.0s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=1, MAE=(train=-0.793, test=-0.756), MSE=(train=-1.187, test=-0.932), R2=(train=0.636, test=0.673), total=   0.0s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=2, MAE=(train=-0.586, test=-0.959), MSE=(train=-0.667, test=-1.853), R2=(train=0.786, test=0.465), total=   0.4s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=2, MAE=(train=-0.628, test=-0.942), MSE=(train=-0.784, test=-2.153), R2=(train=0.755, test=0.312), total=   0.5s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=2, MAE=(train=-0.632, test=-0.816), MSE=(train=-0.787, test=-1.260), R2=(train=0.753, test=0.611), total=   0.4s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=2, MAE=(train=-0.611, test=-0.872), MSE=(train=-0.740, test=-1.460), R2=(train=0.768, test=0.540), total=   0.4s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=2, MAE=(train=-0.634, test=-0.843), MSE=(train=-0.819, test=-1.383), R2=(train=0.749, test=0.516), total=   0.4s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=3, MAE=(train=-0.275, test=-4.290), MSE=(train=-0.229, test=-106.315), R2=(train=0.927, test=-29.688), total=   7.4s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=3, MAE=(train=-0.289, test=-4.758), MSE=(train=-0.276, test=-78.385), R2=(train=0.914, test=-24.055), total=   7.3s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=3, MAE=(train=-0.279, test=-4.287), MSE=(train=-0.274, test=-180.409), R2=(train=0.914, test=-54.716), total=   7.0s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=3, MAE=(train=-0.299, test=-3.936), MSE=(train=-0.271, test=-61.852), R2=(train=0.915, test=-18.485), total=   6.9s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=3, MAE=(train=-0.295, test=-3.532), MSE=(train=-0.290, test=-46.290), R2=(train=0.911, test=-15.214), total=   5.9s
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=4, MAE=(train=-0.113, test=-4.952), MSE=(train=-0.076, test=-185.798), R2=(train=0.976, test=-52.631), total= 1.6min
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=4, MAE=(train=-0.133, test=-4.942), MSE=(train=-0.100, test=-215.256), R2=(train=0.969, test=-67.805), total= 1.4min
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=4, MAE=(train=-0.122, test=-7.725), MSE=(train=-0.097, test=-702.890), R2=(train=0.969, test=-216.076), total= 1.7min
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=4, MAE=(train=-0.130, test=-4.886), MSE=(train=-0.094, test=-238.732), R2=(train=0.971, test=-74.208), total= 1.5min
# [CV] linearregression__fit_intercept=True, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=True, polynomialfeatures__degree=4, MAE=(train=-0.074, test=-29.295), MSE=(train=-0.063, test=-4750.054), R2=(train=0.981, test=-1662.796), total= 3.5min
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=1, MAE=(train=-0.749, test=-0.891), MSE=(train=-1.040, test=-1.539), R2=(train=0.667, test=0.556), total=   0.0s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=1, MAE=(train=-0.782, test=-0.802), MSE=(train=-1.130, test=-1.188), R2=(train=0.647, test=0.620), total=   0.0s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=1, MAE=(train=-0.796, test=-0.738), MSE=(train=-1.172, test=-0.982), R2=(train=0.632, test=0.697), total=   0.1s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=1, MAE=(train=-0.772, test=-0.818), MSE=(train=-1.086, test=-1.336), R2=(train=0.660, test=0.579), total=   0.1s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=1
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=1, MAE=(train=-0.793, test=-0.756), MSE=(train=-1.187, test=-0.932), R2=(train=0.636, test=0.673), total=   0.0s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=2, MAE=(train=-0.586, test=-0.959), MSE=(train=-0.667, test=-1.848), R2=(train=0.786, test=0.466), total=   0.4s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=2, MAE=(train=-0.628, test=-0.941), MSE=(train=-0.784, test=-2.137), R2=(train=0.755, test=0.317), total=   0.3s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=2, MAE=(train=-0.632, test=-0.817), MSE=(train=-0.787, test=-1.259), R2=(train=0.753, test=0.611), total=   0.4s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=2, MAE=(train=-0.611, test=-0.875), MSE=(train=-0.740, test=-1.465), R2=(train=0.768, test=0.539), total=   0.3s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=2
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=2, MAE=(train=-0.634, test=-0.845), MSE=(train=-0.819, test=-1.386), R2=(train=0.749, test=0.515), total=   0.4s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=3, MAE=(train=-0.275, test=-4.291), MSE=(train=-0.229, test=-104.150), R2=(train=0.927, test=-29.063), total=   8.8s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=3, MAE=(train=-0.289, test=-4.694), MSE=(train=-0.276, test=-75.526), R2=(train=0.914, test=-23.141), total=   9.3s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=3, MAE=(train=-0.279, test=-4.305), MSE=(train=-0.274, test=-179.888), R2=(train=0.914, test=-54.556), total=   7.1s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=3, MAE=(train=-0.299, test=-3.916), MSE=(train=-0.271, test=-60.831), R2=(train=0.915, test=-18.163), total=   6.9s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=3
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=3, MAE=(train=-0.295, test=-3.529), MSE=(train=-0.290, test=-46.231), R2=(train=0.911, test=-15.193), total=   5.2s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=4, MAE=(train=-0.113, test=-4.951), MSE=(train=-0.076, test=-185.986), R2=(train=0.976, test=-52.686), total= 1.5min
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=4, MAE=(train=-0.133, test=-4.907), MSE=(train=-0.100, test=-210.648), R2=(train=0.969, test=-66.332), total= 1.6min
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=4, MAE=(train=-0.122, test=-7.969), MSE=(train=-0.098, test=-728.030), R2=(train=0.969, test=-223.841), total= 1.5min
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=4, MAE=(train=-0.130, test=-5.010), MSE=(train=-0.094, test=-249.310), R2=(train=0.971, test=-77.540), total=  52.1s
# [CV] linearregression__fit_intercept=False, polynomialfeatures__degree=4
# [CV]  linearregression__fit_intercept=False, polynomialfeatures__degree=4, MAE=(train=-0.074, test=-29.179), MSE=(train=-0.063, test=-4744.728), R2=(train=0.981, test=-1660.930), total= 2.0min
# Metrics based on the best R²
# - R²: 0.625
# - MAE: 0.801
# - RMSE: 1.093
# - Duration: 0.015
# - Parameters: {'linearregression__fit_intercept': False, 'polynomialfeatures__degree': 1}
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 24.0min finished

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We got the <b>best parameters</b> so, we are going to <b>analyze</b> them more in details
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h5 style="margin: auto; padding: 20px; color:#fff; ">6.1.4.1. Linear Regression and Polynomial Features Validation curve</h5>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Validation curve</b>, we are going to use a <b>range of neighbors</b> to analyze the model through them
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

degree = [1, 2, 3, 4, 5]

reg = make_pipeline(preprocessor, PolynomialFeatures(), LinearRegression(fit_intercept=False))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the validacion curve</b> based on the best parameters
# </div>

# %%
plot_validation_curve(reg, "LinearRegression - Polynomial", X_train, y_train, param_name="polynomialfeatures__degree", param_range=degree, param_name_short="Degree", cv=kfold)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-238-469ea2413709> in <module>
# ----> 1 plot_validation_curve(reg, "LinearRegression - Polynomial", X_train, y_train, param_name="polynomialfeatures__degree", param_range=degree, param_name_short="Degree", cv=kfold)
#
# <ipython-input-158-f56726827ead> in plot_validation_curve(estimator, name_model, X_train, y_train, param_name, param_range, param_name_short, scoring, cv)
#     168
#     169         # Get the validation_curves results
# --> 170         train_scores, test_scores = validation_curve(estimator, X_train, y_train, param_name=param_name, param_range=param_range, cv=kfold)
#     171
#     172         train_scores_mean = np.mean(train_scores, axis=1)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in validation_curve(estimator, X, y, param_name, param_range, groups, cv, scoring, n_jobs, pre_dispatch, verbose, error_score)
#    1495     parallel = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch,
#    1496                         verbose=verbose)
# -> 1497     out = parallel(delayed(_fit_and_score)(
#    1498         clone(estimator), X, y, scorer, train, test, verbose,
#    1499         parameters={param_name: v}, fit_params=None, return_train_score=True,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     558     else:
#     559         fit_time = time.time() - start_time
# --> 560         test_scores = _score(estimator, X_test, y_test, scorer)
#     561         score_time = time.time() - start_time - fit_time
#     562         if return_train_score:
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _score(estimator, X_test, y_test, scorer)
#     605         scores = scorer(estimator, X_test)
#     606     else:
# --> 607         scores = scorer(estimator, X_test, y_test)
#     608
#     609     error_msg = ("scoring must return a number, got %s (%s) "
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     370 def _passthrough_scorer(estimator, *args, **kwargs):
#     371     """Function that wraps estimator.score"""
# --> 372     return estimator.score(*args, **kwargs)
#     373
#     374
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in score(self, X, y, sample_weight)
#     605         Xt = X
#     606         for _, name, transform in self._iter(with_final=False):
# --> 607             Xt = transform.transform(Xt)
#     608         score_params = {}
#     609         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#    1558         if sparse.isspmatrix_csr(X):
#    1559             if self.degree > 3:
# -> 1560                 return self.transform(X.tocsc()).tocsr()
#    1561             to_stack = []
#    1562             if self.include_bias:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#    1584                         out_col = 1
#    1585                         for col_idx in comb:
# -> 1586                             out_col = X[:, col_idx].multiply(out_col)
#    1587                         columns.append(out_col)
#    1588                     else:
#
# ~\anaconda3\lib\site-packages\scipy\sparse\_index.py in __getitem__(self, key)
#      43         elif isinstance(row, slice):
#      44             if isinstance(col, INT_TYPES):
# ---> 45                 return self._get_sliceXint(row, col)
#      46             elif isinstance(col, slice):
#      47                 if row == slice(None) and row == col:
#
# ~\anaconda3\lib\site-packages\scipy\sparse\csc.py in _get_sliceXint(self, row, col)
#     214     def _get_sliceXint(self, row, col):
#     215         if row.step in (1, None):
# --> 216             return self._get_submatrix(major=col, minor=row, copy=True)
#     217         return self._get_submatrix(major=col)._minor_slice(row)
#     218
#
# ~\anaconda3\lib\site-packages\scipy\sparse\compressed.py in _get_submatrix(self, major, minor, copy)
#     789             return self.copy() if copy else self
#     790
# --> 791         indptr, indices, data = get_csr_submatrix(
#     792             M, N, self.indptr, self.indices, self.data, i0, i1, j0, j1)
#     793
#
# KeyboardInterrupt:

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     It is necessary to remenber that we are treating with Non-linear Dataset.
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h5 style="margin: auto; padding: 20px; color:#fff; ">6.1.4.2. Linear Regression and Polynomial Features Learning curve</h5>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Learning curve</b>, we are going to use the <b>best  parameters</b> to analyze the model
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

reg = make_pipeline(preprocessor, PolynomialFeatures(degree=2), LinearRegression(fit_intercept=False))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the learning curve</b> based on the best parameters
# </div>

# %%
plot_learning_curve(reg, "LinearRegression - Polynomial", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h5 style="margin: auto; padding: 20px; color:#fff; ">6.1.4.3. Linear Regression and Polynomial Features predictions validations</h5>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>predictions validations</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> and <b>predicting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, PolynomialFeatures(degree=2), LinearRegression(fit_intercept=False))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Cross-Validated Predictions</b> based on the best parameters for <b>training data</b>
# </div>

# %%
# Making the prediction using the testing data
plot_cross_val_predi(reg, "LinearRegression - Polynomial", "SiteEnergyUse(kBtu)", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h5 style="margin: auto; padding: 20px; color:#fff; ">6.1.4.4. Linear Regression and Polynomial Features Features Importance</h5>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Features Importance</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> values</b>
# </div>

# %%
reg = make_pipeline(preprocessor, PolynomialFeatures(degree=2), LinearRegression(fit_intercept=False))

reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['NumberofFloors',
#                                                    'NumberofBuildings',
#                                                    'BuildingAge',
#                                                    'PropertyGFAParking',
#                                                    'PropertyGFABuilding(s)',
#                                                    'Electricity_ratio']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Neighborhood',
#                                                    'renamed_PropertyType'])])),
#                 ('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression(fit_intercept=False))])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Features Importance</b> based on the best parameters
# </div>

# %%
plot_features_importance(reg, "LinearRegression - Polynomial", X_train, y_train, scoring="neg_mean_squared_error")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.1.5 Predictions metrics</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>To make the comparison among predictions metrics, we are going to select the Linear Regresion without the transformation through Polynomial Features.</p>
#
#     <p>At the same time, we are going to make the prediction with the testing set to compare the result with the model in default mode</p>
# </div>

# %%
start_time_model = timeit.default_timer()

reg = make_pipeline(preprocessor, LinearRegression(copy_X=True, fit_intercept=False))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

end_time_model =  round(timeit.default_timer() - start_time_model, 3)

# Calculating R2 Coefficient of determination for each model (Best possible score is 1.0, lower values are worse.)
R2SCORE = round(r2_score(y_test, y_pred), 5)
    
# Calculating the Mean absolute error (The best value is 0.0)
MAE = round(mean_absolute_error(y_test, y_pred), 3)
    
# Calculating Root Mean Square Error for each model (The best value is 0.0)
RMSE = round(mean_squared_error(y_test, y_pred, squared=False), 3)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding the prediction to compare at the end
# </div>

# %%
# Concatenating predictions to compare against y_test_transformed
df_temp = pd.DataFrame({
    "Model" : "LinearRegression",
    "y_pred" : y_pred
})

# %%
# Concatenating predictions to compare against y_test_transformed
df_y_pred_gsc = pd.concat([df_y_pred_gsc, df_temp])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Verifying the prediction model into the dataset
# </div>

# %%
df_y_pred_gsc["Model"].unique()
# Out:
# array(['Original', 'LinearRegression'], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding metrics to compare at the end
# </div>

# %%
df_temp = pd.DataFrame({
    "Model" : ["LinearRegression"],
    "R2".translate(SUP) : [R2SCORE], 
    "MAE" : [MAE],    
    "RMSE" : [RMSE],
    "Duration" : [end_time_model]
})

# %%
# Concatenating metrics to compare against model with default parameters
df_models_metrics_gsc = pd.concat([df_models_metrics_gsc, df_temp])

# %%
df_models_metrics_gsc
# Out:
#               Model       R²   MAE  RMSE  Duration
# 0  LinearRegression  0.58396  0.84   1.1     0.023

# %%
df_models_metrics
# Out:
#                Model     R²    MAE   RMSE  Duration
# 0             Linear  0.584  0.840  1.100     0.065
# 1         KNeighbors  0.416  0.990  1.304     0.074
# 2              Lasso  0.176  1.218  1.548     0.035
# 3                SVR  0.612  0.794  1.062     0.196
# 4      Random Forest  0.605  0.812  1.072     2.437
# 5  Gradient Boosting  0.638  0.782  1.026     0.292

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Compared to the model with default parameters, we can see that the result (for Linear Regression) is the same
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">6.2. KNeighbors optimization</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Initializing model
# </div>

# %%
knn = KNeighborsRegressor()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Data preprocessing based on the pipelines and the regressors setup
# </div>

# %%
reg = make_pipeline(preprocessor, knn)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Identifying the names of each parameter
# </div>

# %%
sorted(reg.get_params().keys())
# Out:
# ['columntransformer',
#  'columntransformer__n_jobs',
#  'columntransformer__pipeline-1',
#  'columntransformer__pipeline-1__memory',
#  'columntransformer__pipeline-1__standardscaler',
#  'columntransformer__pipeline-1__standardscaler__copy',
#  'columntransformer__pipeline-1__standardscaler__with_mean',
#  'columntransformer__pipeline-1__standardscaler__with_std',
#  'columntransformer__pipeline-1__steps',
#  'columntransformer__pipeline-1__verbose',
#  'columntransformer__pipeline-2',
#  'columntransformer__pipeline-2__memory',
#  'columntransformer__pipeline-2__onehotencoder',
#  'columntransformer__pipeline-2__onehotencoder__categories',
#  'columntransformer__pipeline-2__onehotencoder__drop',
#  'columntransformer__pipeline-2__onehotencoder__dtype',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown',
#  'columntransformer__pipeline-2__onehotencoder__sparse',
#  'columntransformer__pipeline-2__steps',
#  'columntransformer__pipeline-2__verbose',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'kneighborsregressor',
#  'kneighborsregressor__algorithm',
#  'kneighborsregressor__leaf_size',
#  'kneighborsregressor__metric',
#  'kneighborsregressor__metric_params',
#  'kneighborsregressor__n_jobs',
#  'kneighborsregressor__n_neighbors',
#  'kneighborsregressor__p',
#  'kneighborsregressor__weights',
#  'memory',
#  'steps',
#  'verbose']

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Parameters settings
# </div>

# %%
param_grid = {
    "kneighborsregressor__n_neighbors" : [3, 5, 7, 9, 11, 13, 15, 20, 50], # Number of neighbors to use by default for kneighbors queries.
    "kneighborsregressor__metric" : ["euclidean", "manhattan"] # The distance metric to use for the tree.
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Executing the model
# </div>

# %%
# K-Folds cross-validator
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

search = GridSearchCV(reg, param_grid, n_jobs=-1, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True)

search.fit(X_train, y_train)

# Transforming the result to dataframe format
df_results = pd.DataFrame(search.cv_results_)

# Get the results
print("Metrics based on the best R2".translate(SUP))
print("- R2:".translate(SUP), round(search.best_score_, 3))
print("- MAE:", round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
print("- RMSE:", round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
print("- Duration:", round(df_results.iloc[search.best_index_]["mean_score_time"], 3))
print("- Parameters:", search.best_params_)
# Out:
# Metrics based on the best R²
# - R²: 0.603
# - MAE: 0.831
# - RMSE: 1.127
# - Duration: 0.03
# - Parameters: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 13}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We got the <b>best parameters</b> so, we are going to <b>analyze</b> them more in details
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.2.1 KNeighbors Validation curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Validation curve</b>, we are going to use a <b>range of neighbors</b> to analyze the model through them
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

n_neighbors = [3, 5, 7, 9, 11, 13, 15, 20, 50]

reg = make_pipeline(preprocessor, KNeighborsRegressor(metric="euclidean"))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the validacion curve</b> based on the best parameters
# </div>

# %%
plot_validation_curve(reg, "KNeighbors", X_train, y_train, param_name="kneighborsregressor__n_neighbors", param_range=n_neighbors, param_name_short="Neighbors", cv=kfold)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#
#
#     <ul style="list-style-type: square;">
#         <li>For <b>Neighbors values of 15 to 50</b>, we can see a <b>High Bias</b> and <b>Low Variance</b> so, for this parameters the model is <b>Underfitting</b> maybe due to have a poor feature set <br>or the relationships in the data are inherently</li>
#         <li>For <b>Neighbors values of 3 to 11</b>, we have a poorly performs for train and validation set so, for this parameters the model is <b>Underfitting</b> as well</li>
#         <li>The best result if for <b>Neighbors value of 13</b> but, like the previous point we have a poorly performs for both sets. So, in general the model is <b>Underfitting</b></li>
#     </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.2.2 KNeighbors Learning curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Learning curve</b>, we are going to use the <b>best  parameters</b> to analyze the model
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

reg = make_pipeline(preprocessor, KNeighborsRegressor(n_neighbors=13, metric="euclidean"))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the learning curve</b> based on the best parameters
# </div>

# %%
plot_learning_curve(reg, "kneighbors", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.2.3 KNeighbors predictions validations</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>predictions validations</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> and <b>predicting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, KNeighborsRegressor(n_neighbors=13, metric="euclidean"))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Cross-Validated Predictions</b> based on the best parameters for <b>training data</b>
# </div>

# %%
# Making the prediction using the testing data
plot_cross_val_predi(reg, "KNeighbors", "SiteEnergyUse(kBtu)", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.2.4 KNeighbors Features Importance</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Features Importance</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> values</b>
# </div>

# %%
reg = make_pipeline(preprocessor, KNeighborsRegressor(n_neighbors=13, metric="euclidean"))

reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['NumberofFloors',
#                                                    'NumberofBuildings',
#                                                    'BuildingAge',
#                                                    'PropertyGFAParking',
#                                                    'PropertyGFABuilding(s)',
#                                                    'Electricity_ratio']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Neighborhood',
#                                                    'renamed_PropertyType'])])),
#                 ('kneighborsregressor',
#                  KNeighborsRegressor(metric='euclidean', n_neighbors=13))])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Features Importance</b> based on the best parameters
# </div>

# %%
plot_features_importance(reg, "KNeighbors", X_train, y_train, scoring="neg_mean_squared_error")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.2.5 Find the k Nearest Neighbors</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We are going to <b>process data</b> directly with <b>make_column_transformer</b> already defined
# </div>

# %%
X_train_transformed = preprocessor.fit_transform(X_train)

# %%
X_train_transformed.shape
# Out:
# (1085, 27)

# %%
X_test_transformed = preprocessor.fit_transform(X_test)

# %%
X_test_transformed.shape
# Out:
# (466, 27)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Now, we are going to select <b>one random sample</b> of X_test to find its Neighbors
# </div>

# %%
seed(0)

# considering the X_test shape
indice = randint(0, 496, 1)
indice
# Out:
# array([172])

# %%
X_test_sample_transformed = X_test_transformed[indice]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Initializing model
# </div>

# %%
nbrs = NearestNeighbors(n_neighbors=13, metric="euclidean")

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Fitting the NearestNeighbors
# </div>

# %%
nbrs.fit(X_train_transformed)
# Out:
# NearestNeighbors(metric='euclidean', n_neighbors=13)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Finding the neighbors
# </div>

# %%
distances, indices = nbrs.kneighbors(X_test_sample_transformed)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Sample selected
# </div>

# %%
X_test.iloc[indice]
# Out:
#       NumberofFloors  NumberofBuildings  BuildingAge  PropertyGFAParking  \
# 1194             1.0                1.0         61.0                 0.0
#
#       PropertyGFABuilding(s)      Neighborhood renamed_PropertyType  \
# 1194               16.161447  GREATER DUWAMISH            Warehouse
#
#       Electricity_ratio
# 1194           51.23561

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Sample selected neighbors
# </div>

# %%
X_train.iloc[indices[0].tolist()]
# Out:
#       NumberofFloors  NumberofBuildings  BuildingAge  PropertyGFAParking  \
# 1198             1.0                1.0         52.0                 0.0
# 1161             1.0                1.0         54.0                 0.0
# 1350             1.0                1.0         59.0                 0.0
# 1286             1.0                1.0         61.0                 0.0
# 1179             2.0                1.0         59.0                 0.0
# 1195             2.0                1.0         69.0                 0.0
# 1318             1.0                1.0         53.0                 0.0
# 1167             1.0                1.0         41.0                 0.0
# 1204             1.0                1.0         43.0                 0.0
# 1333             1.0                1.0         80.0                 0.0
# 1214             1.0                1.0         52.0                 0.0
# 1174             1.0                1.0         64.0                 0.0
# 1259             1.0                1.0         60.0                 0.0
#
#       PropertyGFABuilding(s)      Neighborhood renamed_PropertyType  \
# 1198               15.758900  GREATER DUWAMISH            Warehouse
# 1161               15.611515  GREATER DUWAMISH            Warehouse
# 1350               15.458791  GREATER DUWAMISH            Warehouse
# 1286               15.708599  GREATER DUWAMISH            Warehouse
# 1179               16.501713  GREATER DUWAMISH            Warehouse
# 1195               16.819630  GREATER DUWAMISH            Warehouse
# 1318               15.559138  GREATER DUWAMISH            Warehouse
# 1167               15.683132  GREATER DUWAMISH            Warehouse
# 1204               15.883407  GREATER DUWAMISH            Warehouse
# 1333               15.577252  GREATER DUWAMISH            Warehouse
# 1214               15.188859  GREATER DUWAMISH            Warehouse
# 1174               15.633449  GREATER DUWAMISH            Warehouse
# 1259               15.354490  GREATER DUWAMISH            Warehouse
#
#       Electricity_ratio
# 1198           55.02730
# 1161           56.91532
# 1350           50.25414
# 1286           38.28613
# 1179           66.07499
# 1195           57.04262
# 1318           62.11921
# 1167           51.76079
# 1204           63.29032
# 1333           53.12373
# 1214           53.42718
# 1174           29.50885
# 1259           68.21846

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Mean values for features and target based on neighbors
# </div>

# %%
X_train.iloc[indices[0].tolist()].mean()
# Out:
# NumberofFloors             1.153846
# NumberofBuildings          1.000000
# BuildingAge               57.461538
# PropertyGFAParking         0.000000
# PropertyGFABuilding(s)    15.749144
# Electricity_ratio         54.234542
# dtype: float64

# %%
y_train.iloc[indices[0].tolist()].mean()
# Out:
# 21.00657290727767

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Real values for test
# </div>

# %%
y_test.iloc[indice]
# Out:
# 1194    21.11139
# Name: SiteEnergyUse(kBtu), dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
#     At this point, we can see that the prediction is very close to real value
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.2.6 Predictions metrics</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We are going to make the prediction with the testing set to compare the result with the model in default mode
# </div>

# %%
start_time_model = timeit.default_timer()

reg = make_pipeline(preprocessor, KNeighborsRegressor(n_neighbors=13, metric="euclidean"))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

end_time_model =  round(timeit.default_timer() - start_time_model, 3)

# Calculating R2 Coefficient of determination for each model (Best possible score is 1.0, lower values are worse.)
R2SCORE = round(r2_score(y_test, y_pred), 5)
    
# Calculating the Mean absolute error (The best value is 0.0)
MAE = round(mean_absolute_error(y_test, y_pred), 3)
    
# Calculating Root Mean Square Error for each model (The best value is 0.0)
RMSE = round(mean_squared_error(y_test, y_pred, squared=False), 3)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding the prediction to compare at the end
# </div>

# %%
# Concatenating predictions to compare against y_test_transformed
df_temp = pd.DataFrame({
    "Model" : "KNeighbors",
    "y_pred" : y_pred
})

# %%
# Concatenating predictions to compare against y_test_transformed
df_y_pred_gsc = pd.concat([df_y_pred_gsc, df_temp])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Verifying the prediction model into the dataset
# </div>

# %%
df_y_pred_gsc["Model"].unique()
# Out:
# array(['Original', 'LinearRegression', 'KNeighbors'], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding metrics to compare at the end
# </div>

# %%
df_temp = pd.DataFrame({
    "Model" : ["KNeighbors"],
    "R2".translate(SUP) : [R2SCORE], 
    "MAE" : [MAE],    
    "RMSE" : [RMSE],
    "Duration" : [end_time_model]
})

# %%
# Concatenating metrics to compare against model with default parameters
df_models_metrics_gsc = pd.concat([df_models_metrics_gsc, df_temp])

# %%
df_models_metrics_gsc
# Out:
#               Model       R²    MAE   RMSE  Duration
# 0  LinearRegression  0.58396  0.840  1.100     0.023
# 0        KNeighbors  0.56379  0.856  1.127     0.043

# %%
df_models_metrics
# Out:
#                Model     R²    MAE   RMSE  Duration
# 0             Linear  0.584  0.840  1.100     0.065
# 1         KNeighbors  0.416  0.990  1.304     0.074
# 2              Lasso  0.176  1.218  1.548     0.035
# 3                SVR  0.612  0.794  1.062     0.196
# 4      Random Forest  0.605  0.812  1.072     2.437
# 5  Gradient Boosting  0.638  0.782  1.026     0.292

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Compared to the model with default parameters, we can see that the result (for Linear Regression) has improved
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">6.3. Lasso optimization</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Initializing model
# </div>

# %%
ls = Lasso()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Data preprocessing based on the pipelines and the regressors setup
# </div>

# %%
reg = make_pipeline(preprocessor, ls)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Identifying the names of each parameter
# </div>

# %%
sorted(reg.get_params().keys())
# Out:
# ['columntransformer',
#  'columntransformer__n_jobs',
#  'columntransformer__pipeline-1',
#  'columntransformer__pipeline-1__memory',
#  'columntransformer__pipeline-1__standardscaler',
#  'columntransformer__pipeline-1__standardscaler__copy',
#  'columntransformer__pipeline-1__standardscaler__with_mean',
#  'columntransformer__pipeline-1__standardscaler__with_std',
#  'columntransformer__pipeline-1__steps',
#  'columntransformer__pipeline-1__verbose',
#  'columntransformer__pipeline-2',
#  'columntransformer__pipeline-2__memory',
#  'columntransformer__pipeline-2__onehotencoder',
#  'columntransformer__pipeline-2__onehotencoder__categories',
#  'columntransformer__pipeline-2__onehotencoder__drop',
#  'columntransformer__pipeline-2__onehotencoder__dtype',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown',
#  'columntransformer__pipeline-2__onehotencoder__sparse',
#  'columntransformer__pipeline-2__steps',
#  'columntransformer__pipeline-2__verbose',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'lasso',
#  'lasso__alpha',
#  'lasso__copy_X',
#  'lasso__fit_intercept',
#  'lasso__max_iter',
#  'lasso__normalize',
#  'lasso__positive',
#  'lasso__precompute',
#  'lasso__random_state',
#  'lasso__selection',
#  'lasso__tol',
#  'lasso__warm_start',
#  'memory',
#  'steps',
#  'verbose']

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Parameters settings
# </div>

# %%
param_grid = {
    "lasso__alpha" : np.arange(0.01, 1, 0.01), # Constant that multiplies the L1 term.
    "lasso__copy_X" : [True, False], # If True, X will be copied; else, it may be overwritten.
    "lasso__fit_intercept" : [True, False] # Whether to calculate the intercept for this model.
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Executing the model
# </div>

# %%
# K-Folds cross-validator
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

search = GridSearchCV(reg, param_grid, n_jobs=-2, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True)

search.fit(X_train, y_train)

# Transforming the result to dataframe format
df_results = pd.DataFrame(search.cv_results_)

# Get the results
print("Metrics based on the best R2".translate(SUP))
print("- R2:".translate(SUP), round(search.best_score_, 3))
print("- MAE:", round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
print("- RMSE:", round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
print("- Duration:", round(df_results.iloc[search.best_index_]["mean_score_time"], 3))
print("- Parameters:", search.best_params_)
# Out:
# Metrics based on the best R²
# - R²: 0.629
# - MAE: 0.797
# - RMSE: 1.09
# - Duration: 0.008
# - Parameters: {'lasso__alpha': 0.01, 'lasso__copy_X': True, 'lasso__fit_intercept': True}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We got the <b>best parameters</b> so, we are going to <b>analyze</b> them more in details
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.3.1 Lasso Validation curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Validation curve</b>, we are going to use a <b>range of alpha</b> to analyze the model through them
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

alpha = np.arange(0.01, 1, 0.01).tolist()

reg = make_pipeline(preprocessor, Lasso(copy_X=True, fit_intercept=True))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the validacion curve</b> based on the best parameters
# </div>

# %%
plot_validation_curve(reg, "Lasso", X_train, y_train, param_name="lasso__alpha", param_range=alpha, param_name_short="alpha", cv=kfold)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#
#     <p>As you go through <b>alpha</b> you can see how the score decrease. We can say that the model is <b>Underfitting</b> maybe due to have a poor feature set <br>or the relationships in the data are inherently</p>
#     <p>We have have to consider that <b>Lasso</b> is a type of regularized linear regression that includes an L1 penalsy so, it considers a Linear regresion among the features and the targed. On the other hand, we are working with a Non-linear dataset.</p>
#
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.3.2 Lasso Learning curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Learning curve</b>, we are going to use the <b>best  parameters</b> to analyze the model
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

reg = make_pipeline(preprocessor, Lasso(alpha=0.01, copy_X=True, fit_intercept=True))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the learning curve</b> based on the best parameters
# </div>

# %%
plot_learning_curve(reg, "Lasso", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.3.3 Lasso predictions validations</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>predictions validations</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> and <b>predicting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, Lasso(alpha=0.01, copy_X=True, fit_intercept=True))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Cross-Validated Predictions</b> based on the best parameters for <b>training data</b>
# </div>

# %%
# Making the prediction using the testing data
plot_cross_val_predi(reg, "Lasso", "SiteEnergyUse(kBtu)", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.3.4 Lasso Features Importance</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Features Importance</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> values</b>
# </div>

# %%
reg = make_pipeline(preprocessor, Lasso(alpha=0.01, copy_X=True, fit_intercept=True))

reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['NumberofFloors',
#                                                    'NumberofBuildings',
#                                                    'BuildingAge',
#                                                    'PropertyGFAParking',
#                                                    'PropertyGFABuilding(s)',
#                                                    'Electricity_ratio']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Neighborhood',
#                                                    'renamed_PropertyType'])])),
#                 ('lasso', Lasso(alpha=0.01))])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Features Importance</b> based on the best parameters
# </div>

# %%
plot_features_importance(reg, "Lasso", X_train, y_train, scoring="neg_mean_squared_error")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.3.5 Predictions metrics</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We are going to make the prediction with the testing set to compare the result with the model in default mode
# </div>

# %%
start_time_model = timeit.default_timer()

reg = make_pipeline(preprocessor, Lasso(alpha=0.01, copy_X=True, fit_intercept=True))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

end_time_model =  round(timeit.default_timer() - start_time_model, 3)

# Calculating R2 Coefficient of determination for each model (Best possible score is 1.0, lower values are worse.)
R2SCORE = round(r2_score(y_test, y_pred), 5)
    
# Calculating the Mean absolute error (The best value is 0.0)
MAE = round(mean_absolute_error(y_test, y_pred), 3)
    
# Calculating Root Mean Square Error for each model (The best value is 0.0)
RMSE = round(mean_squared_error(y_test, y_pred, squared=False), 3)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding the prediction to compare at the end
# </div>

# %%
# Concatenating predictions to compare against y_test_transformed
df_temp = pd.DataFrame({
    "Model" : "Lasso",
    "y_pred" : y_pred
})

# %%
# Concatenating predictions to compare against y_test_transformed
df_y_pred_gsc = pd.concat([df_y_pred_gsc, df_temp])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Verifying the prediction model into the dataset
# </div>

# %%
df_y_pred_gsc["Model"].unique()
# Out:
# array(['Original', 'LinearRegression', 'KNeighbors', 'Lasso'],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding metrics to compare at the end
# </div>

# %%
df_temp = pd.DataFrame({
    "Model" : ["Lasso"],
    "R2".translate(SUP) : [R2SCORE], 
    "MAE" : [MAE],    
    "RMSE" : [RMSE],
    "Duration" : [end_time_model]
})

# %%
# Concatenating metrics to compare against model with default parameters
df_models_metrics_gsc = pd.concat([df_models_metrics_gsc, df_temp])

# %%
df_models_metrics_gsc
# Out:
#               Model       R²    MAE   RMSE  Duration
# 0  LinearRegression  0.58396  0.840  1.100     0.023
# 0        KNeighbors  0.56379  0.856  1.127     0.043
# 0             Lasso  0.59270  0.825  1.089     0.016

# %%
df_models_metrics
# Out:
#                Model     R²    MAE   RMSE  Duration
# 0             Linear  0.584  0.840  1.100     0.065
# 1         KNeighbors  0.416  0.990  1.304     0.074
# 2              Lasso  0.176  1.218  1.548     0.035
# 3                SVR  0.612  0.794  1.062     0.196
# 4      Random Forest  0.605  0.812  1.072     2.437
# 5  Gradient Boosting  0.638  0.782  1.026     0.292

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Compared to the model with default parameters, we can see how the result improved for Lasso
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">6.4. SVR optimization</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Initializing model
# </div>

# %%
svr = SVR()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Data preprocessing based on the pipelines and the regressors setup
# </div>

# %%
reg = make_pipeline(preprocessor, svr)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Identifying the names of each parameter
# </div>

# %%
sorted(reg.get_params().keys())
# Out:
# ['columntransformer',
#  'columntransformer__n_jobs',
#  'columntransformer__pipeline-1',
#  'columntransformer__pipeline-1__memory',
#  'columntransformer__pipeline-1__standardscaler',
#  'columntransformer__pipeline-1__standardscaler__copy',
#  'columntransformer__pipeline-1__standardscaler__with_mean',
#  'columntransformer__pipeline-1__standardscaler__with_std',
#  'columntransformer__pipeline-1__steps',
#  'columntransformer__pipeline-1__verbose',
#  'columntransformer__pipeline-2',
#  'columntransformer__pipeline-2__memory',
#  'columntransformer__pipeline-2__onehotencoder',
#  'columntransformer__pipeline-2__onehotencoder__categories',
#  'columntransformer__pipeline-2__onehotencoder__drop',
#  'columntransformer__pipeline-2__onehotencoder__dtype',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown',
#  'columntransformer__pipeline-2__onehotencoder__sparse',
#  'columntransformer__pipeline-2__steps',
#  'columntransformer__pipeline-2__verbose',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'memory',
#  'steps',
#  'svr',
#  'svr__C',
#  'svr__cache_size',
#  'svr__coef0',
#  'svr__degree',
#  'svr__epsilon',
#  'svr__gamma',
#  'svr__kernel',
#  'svr__max_iter',
#  'svr__shrinking',
#  'svr__tol',
#  'svr__verbose',
#  'verbose']

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Parameters settings
# </div>

# %%
param_grid = {
    "svr__kernel" : ["linear", "poly", "rbf"], # Specifies the kernel type to be used in the algorithm.
    "svr__gamma" : ["auto", "scale"], # Kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’.
    "svr__C" : [1.5, 10], # Regularization parameter. The strength of the regularization is inversely proportional to C.
    "svr__epsilon" : [0.1, 0.2, 0.5, 0.3] # It specifies the epsilon-tube within which no penalty is associated 
                                       # in the training loss function with points predicted within a distance epsilon from the actual value.
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Executing the model
# </div>

# %%
# K-Folds cross-validator
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

search = GridSearchCV(reg, param_grid, n_jobs=1, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True)

search.fit(X_train, y_train)

# Transforming the result to dataframe format
df_results = pd.DataFrame(search.cv_results_)

# Get the results
print("Metrics based on the best R2".translate(SUP))
print("- R2:".translate(SUP), round(search.best_score_, 3))
print("- MAE:", round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
print("- RMSE:", round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
print("- Duration:", round(df_results.iloc[search.best_index_]["mean_score_time"], 3))
print("- Parameters:", search.best_params_)
# Out:
# Metrics based on the best R²
# - R²: 0.665
# - MAE: 0.751
# - RMSE: 1.035
# - Duration: 0.007
# - Parameters: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We got the <b>best parameters</b> so, we are going to <b>analyze</b> them more in details
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.4.1 SVR Validation curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Validation curve</b>, we are going to use a <b>range of alpha</b> to analyze the model through them
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

gamma = np.arange(0.01, 1, 0.01).tolist()

reg = make_pipeline(preprocessor, SVR(C=10, epsilon=0.5, kernel="rbf"))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the validacion curve</b> based on the best parameters
# </div>

# %%
plot_validation_curve(reg, "SVR", X_train, y_train, param_name="svr__gamma", param_range=gamma, param_name_short="gamma", cv=kfold)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Observations / Conclusions</b></p>
#
#     <p>As you go through <b>gamma</b> you can see how the variance increase between train and validation set. We can say that the model is <b>Overfitting</b>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.4.2 SVR Learning curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Learning curve</b>, we are going to use the <b>best  parameters</b> to analyze the model
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=False, random_state=None)

reg = make_pipeline(preprocessor, SVR(C=10, epsilon=0.5, kernel="rbf", gamma="auto"))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the learning curve</b> based on the best parameters
# </div>

# %%
plot_learning_curve(reg, "SVR", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.4.3 SVR predictions validations</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>predictions validations</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> and <b>predicting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, SVR(C=10, epsilon=0.5, kernel="rbf", gamma="auto"))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Cross-Validated Predictions</b> based on the best parameters for <b>training data</b>
# </div>

# %%
# Making the prediction using the testing data
plot_cross_val_predi(reg, "SVR", "SiteEnergyUse(kBtu)", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.4.4 SVR Features Importance</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Features Importance</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> values</b>
# </div>

# %%
reg = make_pipeline(preprocessor, SVR(C=10, epsilon=0.5, kernel="rbf", gamma="auto"))

reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['NumberofFloors',
#                                                    'NumberofBuildings',
#                                                    'BuildingAge',
#                                                    'PropertyGFAParking',
#                                                    'PropertyGFABuilding(s)',
#                                                    'Electricity_ratio']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Neighborhood',
#                                                    'renamed_PropertyType'])])),
#                 ('svr', SVR(C=10, epsilon=0.5, gamma='auto'))])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Features Importance</b> based on the best parameters
# </div>

# %%
plot_features_importance(reg, "SVR", X_train, y_train, scoring="neg_mean_squared_error")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.4.5 Predictions metrics</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We are going to make the prediction with the testing set to compare the result with the model in default mode
# </div>

# %%
start_time_model = timeit.default_timer()

reg = make_pipeline(preprocessor, SVR(C=10, epsilon=0.5, kernel="rbf", gamma="auto"))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

end_time_model =  round(timeit.default_timer() - start_time_model, 3)

# Calculating R2 Coefficient of determination for each model (Best possible score is 1.0, lower values are worse.)
R2SCORE = round(r2_score(y_test, y_pred), 5)
    
# Calculating the Mean absolute error (The best value is 0.0)
MAE = round(mean_absolute_error(y_test, y_pred), 3)
    
# Calculating Root Mean Square Error for each model (The best value is 0.0)
RMSE = round(mean_squared_error(y_test, y_pred, squared=False), 3)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding the prediction to compare at the end
# </div>

# %%
# Concatenating predictions to compare against y_test_transformed
df_temp = pd.DataFrame({
    "Model" : "SVR",
    "y_pred" : y_pred
})

# %%
# Concatenating predictions to compare against y_test_transformed
df_y_pred_gsc = pd.concat([df_y_pred_gsc, df_temp])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Verifying the prediction model into the dataset
# </div>

# %%
df_y_pred_gsc["Model"].unique()
# Out:
# array(['Original', 'LinearRegression', 'KNeighbors', 'Lasso', 'SVR'],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding metrics to compare at the end
# </div>

# %%
df_temp = pd.DataFrame({
    "Model" : ["SVR"],
    "R2".translate(SUP) : [R2SCORE], 
    "MAE" : [MAE],    
    "RMSE" : [RMSE],
    "Duration" : [end_time_model]
})

# %%
# Concatenating metrics to compare against model with default parameters
df_models_metrics_gsc = pd.concat([df_models_metrics_gsc, df_temp])

# %%
df_models_metrics_gsc
# Out:
#               Model       R²    MAE   RMSE  Duration
# 0  LinearRegression  0.58396  0.840  1.100     0.023
# 0        KNeighbors  0.56379  0.856  1.127     0.043
# 0             Lasso  0.59270  0.825  1.089     0.016
# 0               SVR  0.60751  0.790  1.069     0.065

# %%
df_models_metrics
# Out:
#                Model     R²    MAE   RMSE  Duration
# 0             Linear  0.584  0.840  1.100     0.065
# 1         KNeighbors  0.416  0.990  1.304     0.074
# 2              Lasso  0.176  1.218  1.548     0.035
# 3                SVR  0.612  0.794  1.062     0.196
# 4      Random Forest  0.605  0.812  1.072     2.437
# 5  Gradient Boosting  0.638  0.782  1.026     0.292

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Compared to the model with default parameters, we can see how the result decreased for SVR
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">6.6. Gradient Boosting optimization</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Initializing model
# </div>

# %%
gbr = GradientBoostingRegressor()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Data preprocessing based on the pipelines and the regressors setup
# </div>

# %%
reg = make_pipeline(preprocessor, gbr)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Identifying the names of each parameter
# </div>

# %%
sorted(reg.get_params().keys())
# Out:
# ['columntransformer',
#  'columntransformer__n_jobs',
#  'columntransformer__pipeline-1',
#  'columntransformer__pipeline-1__memory',
#  'columntransformer__pipeline-1__standardscaler',
#  'columntransformer__pipeline-1__standardscaler__copy',
#  'columntransformer__pipeline-1__standardscaler__with_mean',
#  'columntransformer__pipeline-1__standardscaler__with_std',
#  'columntransformer__pipeline-1__steps',
#  'columntransformer__pipeline-1__verbose',
#  'columntransformer__pipeline-2',
#  'columntransformer__pipeline-2__memory',
#  'columntransformer__pipeline-2__onehotencoder',
#  'columntransformer__pipeline-2__onehotencoder__categories',
#  'columntransformer__pipeline-2__onehotencoder__drop',
#  'columntransformer__pipeline-2__onehotencoder__dtype',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown',
#  'columntransformer__pipeline-2__onehotencoder__sparse',
#  'columntransformer__pipeline-2__steps',
#  'columntransformer__pipeline-2__verbose',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'gradientboostingregressor',
#  'gradientboostingregressor__alpha',
#  'gradientboostingregressor__ccp_alpha',
#  'gradientboostingregressor__criterion',
#  'gradientboostingregressor__init',
#  'gradientboostingregressor__learning_rate',
#  'gradientboostingregressor__loss',
#  'gradientboostingregressor__max_depth',
#  'gradientboostingregressor__max_features',
#  'gradientboostingregressor__max_leaf_nodes',
#  'gradientboostingregressor__min_impurity_decrease',
#  'gradientboostingregressor__min_impurity_split',
#  'gradientboostingregressor__min_samples_leaf',
#  'gradientboostingregressor__min_samples_split',
#  'gradientboostingregressor__min_weight_fraction_leaf',
#  'gradientboostingregressor__n_estimators',
#  'gradientboostingregressor__n_iter_no_change',
#  'gradientboostingregressor__presort',
#  'gradientboostingregressor__random_state',
#  'gradientboostingregressor__subsample',
#  'gradientboostingregressor__tol',
#  'gradientboostingregressor__validation_fraction',
#  'gradientboostingregressor__verbose',
#  'gradientboostingregressor__warm_start',
#  'memory',
#  'steps',
#  'verbose']

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Parameters settings
# </div>

# %%
param_grid = {
    "gradientboostingregressor__learning_rate" : [0.01, 0.02, 0.03, 0.04],
    "gradientboostingregressor__max_depth" : [2, 4, 6, 8],
    "gradientboostingregressor__n_estimators" : [100, 500, 1000, 1500],
    "gradientboostingregressor__subsample" : [0.9, 0.5, 0.2, 0.1]
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Executing the model
# </div>

# %%
## K-Folds cross-validator
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

search = GridSearchCV(reg, param_grid, n_jobs=1, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True)

search.fit(X_train, y_train)

# Transforming the result to dataframe format
df_results = pd.DataFrame(search.cv_results_)

# Get the results
print("Metrics based on the best R2".translate(SUP))
print("- R2:".translate(SUP), round(search.best_score_, 3))
print("- MAE:", round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
print("- RMSE:", round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
print("- Duration:", round(df_results.iloc[search.best_index_]["mean_score_time"], 3))
print("- Parameters:", search.best_params_)
# Out:
# Metrics based on the best R²
# - R²: 0.683
# - MAE: 0.741
# - RMSE: 1.006
# - Duration: 0.013
# - Parameters: {'gradientboostingregressor__learning_rate': 0.01, 'gradientboostingregressor__max_depth': 2, 'gradientboostingregressor__n_estimators': 1500, 'gradientboostingregressor__subsample': 0.5}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We got the <b>best parameters</b> so, we are going to <b>analyze</b> them more in details
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.6.1 Gradient Boosting Validation curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Validation curve</b>, we are going to use a <b>range of estimators</b> to analyze the model through them
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

n_estimators = np.unique(np.logspace(0, 1.8, num=30).astype(int))

reg = make_pipeline(preprocessor, GradientBoostingRegressor(learning_rate=0.01, max_depth=2, subsample=0.5))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the validacion curve</b> based on the best parameters
# </div>

# %%
plot_validation_curve(reg, "GradientBoostingRegressor", X_train, y_train, param_name="gradientboostingregressor__n_estimators", param_range=n_estimators, param_name_short="Estimators", \
                      scoring="neg_mean_absolute_error", cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.6.2 Gradient Boosting Learning curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Learning curve</b>, we are going to use the <b>best  parameters</b> to analyze the model
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, GradientBoostingRegressor(learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the learning curve</b> based on the best parameters
# </div>

# %%
plot_learning_curve(reg, "GradientBoostingRegressor", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.6.3 Gradient Boosting predictions validations</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>predictions validations</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> and <b>predicting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, GradientBoostingRegressor(learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Cross-Validated Predictions</b> based on the best parameters for <b>training data</b>
# </div>

# %%
# Making the prediction using the testing data
plot_cross_val_predi(reg, "GradientBoostingRegressor", "SiteEnergyUse(kBtu)", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.6.4 Gradient Boosting Features Importance</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Features Importance</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, GradientBoostingRegressor(learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5))

reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['NumberofFloors',
#                                                    'NumberofBuildings',
#                                                    'BuildingAge',
#                                                    'PropertyGFAParking',
#                                                    'PropertyGFABuilding(s)',
#                                                    'Electricity_ratio']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Neighborhood',
#                                                    'renamed_PropertyType'])])),
#                 ('gradientboostingregressor',
#                  GradientBoostingRegressor(learning_rate=0.01, max_depth=2,
#                                            n_estimators=1500, subsample=0.5))])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Features Importance</b> based on the best parameters
# </div>

# %%
plot_features_importance(reg, "GradientBoostingRegressor", X_train, y_train, scoring="neg_mean_squared_error")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.6.5 Predictions metrics</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We are going to make the prediction with the testing set to compare the result with the model in default mode
# </div>

# %%
start_time_model = timeit.default_timer()

reg = make_pipeline(preprocessor,  GradientBoostingRegressor(learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

end_time_model =  round(timeit.default_timer() - start_time_model, 3)

# Calculating R2 Coefficient of determination for each model (Best possible score is 1.0, lower values are worse.)
R2SCORE = round(r2_score(y_test, y_pred), 5)
    
# Calculating the Mean absolute error (The best value is 0.0)
MAE = round(mean_absolute_error(y_test, y_pred), 3)
    
# Calculating Root Mean Square Error for each model (The best value is 0.0)
RMSE = round(mean_squared_error(y_test, y_pred, squared=False), 3)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding the prediction to compare at the end
# </div>

# %%
# Concatenating predictions to compare against y_test_transformed
df_temp = pd.DataFrame({
    "Model" : "GradientBoostingRegressor",
    "y_pred" : y_pred
})

# %%
# Concatenating predictions to compare against y_test_transformed
df_y_pred_gsc = pd.concat([df_y_pred_gsc, df_temp])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Verifying the prediction model into the dataset
# </div>

# %%
df_y_pred_gsc["Model"].unique()
# Out:
# array(['Original', 'LinearRegression', 'KNeighbors', 'Lasso', 'SVR',
#        'GradientBoostingRegressor'], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding metrics to compare at the end
# </div>

# %%
df_temp = pd.DataFrame({
    "Model" : ["GradientBoostingRegressor"],
    "R2".translate(SUP) : [R2SCORE], 
    "MAE" : [MAE],    
    "RMSE" : [RMSE],
    "Duration" : [end_time_model]
})

# %%
# Concatenating metrics to compare against model with default parameters
df_models_metrics_gsc = pd.concat([df_models_metrics_gsc, df_temp])

# %%
df_models_metrics_gsc
# Out:
#                        Model       R²    MAE   RMSE  Duration
# 0           LinearRegression  0.58396  0.840  1.100     0.023
# 0                 KNeighbors  0.56379  0.856  1.127     0.043
# 0                      Lasso  0.59270  0.825  1.089     0.016
# 0                        SVR  0.60751  0.790  1.069     0.065
# 0  GradientBoostingRegressor  0.63594  0.779  1.029     2.652

# %%
df_models_metrics
# Out:
#                Model     R²    MAE   RMSE  Duration
# 0             Linear  0.584  0.840  1.100     0.065
# 1         KNeighbors  0.416  0.990  1.304     0.074
# 2              Lasso  0.176  1.218  1.548     0.035
# 3                SVR  0.612  0.794  1.062     0.196
# 4      Random Forest  0.605  0.812  1.072     2.437
# 5  Gradient Boosting  0.638  0.782  1.026     0.292

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Compared to the model with default parameters, we can see that the result is similar
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h1 style="margin: auto; padding: 20px; color:#fff; ">XXXXXXXXXXXXXXXXXXXXXXXXXXXXX</h1>
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">6.5. Random Forest optimization</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Initializing model
# </div>

# %%
regr = RandomForestRegressor()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Data preprocessing based on the pipelines and the regressors setup
# </div>

# %%
reg = make_pipeline(preprocessor, regr)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Identifying the names of each parameter
# </div>

# %%
sorted(reg.get_params().keys())
# Out:
# ['columntransformer',
#  'columntransformer__n_jobs',
#  'columntransformer__pipeline-1',
#  'columntransformer__pipeline-1__memory',
#  'columntransformer__pipeline-1__standardscaler',
#  'columntransformer__pipeline-1__standardscaler__copy',
#  'columntransformer__pipeline-1__standardscaler__with_mean',
#  'columntransformer__pipeline-1__standardscaler__with_std',
#  'columntransformer__pipeline-1__steps',
#  'columntransformer__pipeline-1__verbose',
#  'columntransformer__pipeline-2',
#  'columntransformer__pipeline-2__memory',
#  'columntransformer__pipeline-2__onehotencoder',
#  'columntransformer__pipeline-2__onehotencoder__categories',
#  'columntransformer__pipeline-2__onehotencoder__drop',
#  'columntransformer__pipeline-2__onehotencoder__dtype',
#  'columntransformer__pipeline-2__onehotencoder__handle_unknown',
#  'columntransformer__pipeline-2__onehotencoder__sparse',
#  'columntransformer__pipeline-2__steps',
#  'columntransformer__pipeline-2__verbose',
#  'columntransformer__remainder',
#  'columntransformer__sparse_threshold',
#  'columntransformer__transformer_weights',
#  'columntransformer__transformers',
#  'columntransformer__verbose',
#  'memory',
#  'randomforestregressor',
#  'randomforestregressor__bootstrap',
#  'randomforestregressor__ccp_alpha',
#  'randomforestregressor__criterion',
#  'randomforestregressor__max_depth',
#  'randomforestregressor__max_features',
#  'randomforestregressor__max_leaf_nodes',
#  'randomforestregressor__max_samples',
#  'randomforestregressor__min_impurity_decrease',
#  'randomforestregressor__min_impurity_split',
#  'randomforestregressor__min_samples_leaf',
#  'randomforestregressor__min_samples_split',
#  'randomforestregressor__min_weight_fraction_leaf',
#  'randomforestregressor__n_estimators',
#  'randomforestregressor__n_jobs',
#  'randomforestregressor__oob_score',
#  'randomforestregressor__random_state',
#  'randomforestregressor__verbose',
#  'randomforestregressor__warm_start',
#  'steps',
#  'verbose']

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Parameters settings
# </div>

# %%
param_grid = {
#     "randomforestregressor__bootstrap" : [True, False],
    "randomforestregressor__max_depth" : [60, 70, 80, 90, 100, 110],
    "randomforestregressor__max_features" : ["auto", "log2", "sqrt"],
    "randomforestregressor__min_samples_leaf" : [1, 2, 3, 4, 5],
    "randomforestregressor__min_samples_split" : [4, 6, 8, 10, 12],
    "randomforestregressor__n_estimators" : [50, 80, 100, 130, 180]
}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Executing the model
# </div>

# %%
## K-Folds cross-validator
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

start_time_model = timeit.default_timer()

# search = GridSearchCV(reg, param_grid, n_jobs=-1, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True)
search = GridSearchCV(reg, param_grid, n_jobs=1, cv=kfold, scoring=SCORINGS, refit="R2", return_train_score=True, verbose=3)

search.fit(X_train, y_train)

# Transforming the result to dataframe format
df_results = pd.DataFrame(search.cv_results_)

# Get the results
print("Metrics based on the best R2".translate(SUP))
print("- R2:".translate(SUP), round(search.best_score_, 3))
print("- MAE:", round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
print("- RMSE:", round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
print("- Duration:", round(df_results.iloc[search.best_index_]["mean_score_time"], 3))
print("- Parameters:", search.best_params_)
# Out:
# Fitting 5 folds for each of 2250 candidates, totalling 11250 fits
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50, MAE=(train=-0.314, test=-0.842), MSE=(train=-0.191, test=-1.508), R2=(train=0.939, test=0.565), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50, MAE=(train=-0.325, test=-0.743), MSE=(train=-0.216, test=-1.066), R2=(train=0.932, test=0.659), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50, MAE=(train=-0.319, test=-0.719), MSE=(train=-0.201, test=-0.920), R2=(train=0.937, test=0.716), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50, MAE=(train=-0.320, test=-0.772), MSE=(train=-0.201, test=-1.153), R2=(train=0.937, test=0.637), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=50, MAE=(train=-0.317, test=-0.747), MSE=(train=-0.214, test=-0.901), R2=(train=0.934, test=0.684), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80, MAE=(train=-0.307, test=-0.836), MSE=(train=-0.183, test=-1.523), R2=(train=0.941, test=0.560), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80, MAE=(train=-0.324, test=-0.748), MSE=(train=-0.213, test=-1.116), R2=(train=0.934, test=0.643), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80, MAE=(train=-0.319, test=-0.703), MSE=(train=-0.205, test=-0.906), R2=(train=0.935, test=0.720), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80, MAE=(train=-0.320, test=-0.765), MSE=(train=-0.203, test=-1.137), R2=(train=0.936, test=0.642), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=80, MAE=(train=-0.319, test=-0.743), MSE=(train=-0.215, test=-0.910), R2=(train=0.934, test=0.681), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100, MAE=(train=-0.309, test=-0.843), MSE=(train=-0.185, test=-1.550), R2=(train=0.941, test=0.553), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100, MAE=(train=-0.316, test=-0.740), MSE=(train=-0.200, test=-1.085), R2=(train=0.937, test=0.653), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100, MAE=(train=-0.314, test=-0.715), MSE=(train=-0.202, test=-0.937), R2=(train=0.936, test=0.711), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100, MAE=(train=-0.315, test=-0.769), MSE=(train=-0.201, test=-1.149), R2=(train=0.937, test=0.638), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=100, MAE=(train=-0.317, test=-0.756), MSE=(train=-0.207, test=-0.925), R2=(train=0.937, test=0.676), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130, MAE=(train=-0.303, test=-0.839), MSE=(train=-0.181, test=-1.531), R2=(train=0.942, test=0.558), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130, MAE=(train=-0.318, test=-0.744), MSE=(train=-0.211, test=-1.070), R2=(train=0.934, test=0.658), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130, MAE=(train=-0.316, test=-0.697), MSE=(train=-0.203, test=-0.892), R2=(train=0.936, test=0.725), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130, MAE=(train=-0.315, test=-0.772), MSE=(train=-0.196, test=-1.148), R2=(train=0.938, test=0.638), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=130, MAE=(train=-0.311, test=-0.751), MSE=(train=-0.198, test=-0.906), R2=(train=0.939, test=0.683), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180, MAE=(train=-0.301, test=-0.842), MSE=(train=-0.176, test=-1.540), R2=(train=0.944, test=0.555), total=   1.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180, MAE=(train=-0.320, test=-0.736), MSE=(train=-0.208, test=-1.063), R2=(train=0.935, test=0.660), total=   1.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180, MAE=(train=-0.317, test=-0.699), MSE=(train=-0.199, test=-0.897), R2=(train=0.937, test=0.723), total=   1.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180, MAE=(train=-0.313, test=-0.758), MSE=(train=-0.191, test=-1.130), R2=(train=0.940, test=0.644), total=   1.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=4, randomforestregressor__n_estimators=180, MAE=(train=-0.314, test=-0.750), MSE=(train=-0.208, test=-0.904), R2=(train=0.936, test=0.683), total=   1.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50, MAE=(train=-0.353, test=-0.846), MSE=(train=-0.250, test=-1.530), R2=(train=0.920, test=0.558), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50, MAE=(train=-0.361, test=-0.746), MSE=(train=-0.264, test=-1.087), R2=(train=0.918, test=0.653), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50, MAE=(train=-0.364, test=-0.701), MSE=(train=-0.260, test=-0.896), R2=(train=0.918, test=0.723), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50, MAE=(train=-0.362, test=-0.761), MSE=(train=-0.254, test=-1.147), R2=(train=0.921, test=0.639), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=50, MAE=(train=-0.360, test=-0.751), MSE=(train=-0.264, test=-0.912), R2=(train=0.919, test=0.680), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80, MAE=(train=-0.349, test=-0.825), MSE=(train=-0.230, test=-1.502), R2=(train=0.926, test=0.566), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80, MAE=(train=-0.372, test=-0.755), MSE=(train=-0.273, test=-1.075), R2=(train=0.915, test=0.656), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80, MAE=(train=-0.366, test=-0.710), MSE=(train=-0.272, test=-0.910), R2=(train=0.915, test=0.719), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80, MAE=(train=-0.366, test=-0.762), MSE=(train=-0.263, test=-1.139), R2=(train=0.918, test=0.641), total=   1.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=80, MAE=(train=-0.360, test=-0.756), MSE=(train=-0.265, test=-0.919), R2=(train=0.919, test=0.678), total=   1.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100, MAE=(train=-0.351, test=-0.843), MSE=(train=-0.237, test=-1.544), R2=(train=0.924, test=0.554), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100, MAE=(train=-0.365, test=-0.746), MSE=(train=-0.271, test=-1.098), R2=(train=0.915, test=0.649), total=   0.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100, MAE=(train=-0.364, test=-0.710), MSE=(train=-0.267, test=-0.900), R2=(train=0.916, test=0.722), total=   0.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100, MAE=(train=-0.364, test=-0.757), MSE=(train=-0.260, test=-1.126), R2=(train=0.919, test=0.645), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=100, MAE=(train=-0.360, test=-0.749), MSE=(train=-0.269, test=-0.898), R2=(train=0.917, test=0.685), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130, MAE=(train=-0.346, test=-0.837), MSE=(train=-0.228, test=-1.522), R2=(train=0.927, test=0.561), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130, MAE=(train=-0.367, test=-0.747), MSE=(train=-0.271, test=-1.070), R2=(train=0.916, test=0.658), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130, MAE=(train=-0.364, test=-0.702), MSE=(train=-0.262, test=-0.888), R2=(train=0.918, test=0.726), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130, MAE=(train=-0.363, test=-0.760), MSE=(train=-0.260, test=-1.121), R2=(train=0.919, test=0.647), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=130, MAE=(train=-0.359, test=-0.748), MSE=(train=-0.268, test=-0.895), R2=(train=0.918, test=0.686), total=   1.1s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180, MAE=(train=-0.348, test=-0.838), MSE=(train=-0.234, test=-1.548), R2=(train=0.925, test=0.553), total=   1.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180, MAE=(train=-0.364, test=-0.747), MSE=(train=-0.268, test=-1.078), R2=(train=0.916, test=0.656), total=   1.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180, MAE=(train=-0.361, test=-0.695), MSE=(train=-0.265, test=-0.874), R2=(train=0.917, test=0.730), total=   1.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180, MAE=(train=-0.361, test=-0.762), MSE=(train=-0.258, test=-1.130), R2=(train=0.919, test=0.644), total=   1.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=6, randomforestregressor__n_estimators=180, MAE=(train=-0.356, test=-0.741), MSE=(train=-0.264, test=-0.890), R2=(train=0.919, test=0.688), total=   2.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50, MAE=(train=-0.398, test=-0.852), MSE=(train=-0.296, test=-1.563), R2=(train=0.905, test=0.549), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50, MAE=(train=-0.412, test=-0.748), MSE=(train=-0.342, test=-1.073), R2=(train=0.893, test=0.657), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50, MAE=(train=-0.408, test=-0.710), MSE=(train=-0.321, test=-0.911), R2=(train=0.899, test=0.719), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50, MAE=(train=-0.403, test=-0.773), MSE=(train=-0.314, test=-1.172), R2=(train=0.902, test=0.631), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=50, MAE=(train=-0.405, test=-0.737), MSE=(train=-0.327, test=-0.887), R2=(train=0.900, test=0.689), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80, MAE=(train=-0.391, test=-0.833), MSE=(train=-0.289, test=-1.536), R2=(train=0.908, test=0.557), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80, MAE=(train=-0.413, test=-0.762), MSE=(train=-0.342, test=-1.120), R2=(train=0.893, test=0.642), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80, MAE=(train=-0.409, test=-0.705), MSE=(train=-0.324, test=-0.917), R2=(train=0.898, test=0.717), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80, MAE=(train=-0.403, test=-0.764), MSE=(train=-0.313, test=-1.155), R2=(train=0.902, test=0.636), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=80, MAE=(train=-0.403, test=-0.753), MSE=(train=-0.325, test=-0.921), R2=(train=0.900, test=0.677), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100, MAE=(train=-0.388, test=-0.834), MSE=(train=-0.280, test=-1.519), R2=(train=0.910, test=0.561), total=   0.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100, MAE=(train=-0.405, test=-0.749), MSE=(train=-0.321, test=-1.077), R2=(train=0.900, test=0.656), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100, MAE=(train=-0.405, test=-0.708), MSE=(train=-0.318, test=-0.919), R2=(train=0.900, test=0.716), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100, MAE=(train=-0.401, test=-0.765), MSE=(train=-0.313, test=-1.119), R2=(train=0.902, test=0.647), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=100, MAE=(train=-0.401, test=-0.747), MSE=(train=-0.325, test=-0.902), R2=(train=0.900, test=0.684), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130, MAE=(train=-0.390, test=-0.846), MSE=(train=-0.285, test=-1.536), R2=(train=0.909, test=0.557), total=   0.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130, MAE=(train=-0.406, test=-0.736), MSE=(train=-0.321, test=-1.054), R2=(train=0.900, test=0.663), total=   0.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130, MAE=(train=-0.401, test=-0.698), MSE=(train=-0.308, test=-0.892), R2=(train=0.903, test=0.724), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130, MAE=(train=-0.405, test=-0.774), MSE=(train=-0.313, test=-1.155), R2=(train=0.902, test=0.636), total=   0.9s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=130, MAE=(train=-0.402, test=-0.748), MSE=(train=-0.328, test=-0.899), R2=(train=0.900, test=0.685), total=   0.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180, MAE=(train=-0.388, test=-0.836), MSE=(train=-0.285, test=-1.525), R2=(train=0.909, test=0.560), total=   1.1s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180, MAE=(train=-0.407, test=-0.740), MSE=(train=-0.328, test=-1.075), R2=(train=0.898, test=0.656), total=   1.1s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180, MAE=(train=-0.405, test=-0.710), MSE=(train=-0.316, test=-0.905), R2=(train=0.901, test=0.720), total=   1.1s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180, MAE=(train=-0.401, test=-0.760), MSE=(train=-0.303, test=-1.136), R2=(train=0.905, test=0.642), total=   1.2s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=8, randomforestregressor__n_estimators=180, MAE=(train=-0.400, test=-0.747), MSE=(train=-0.324, test=-0.899), R2=(train=0.901, test=0.685), total=   1.1s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50, MAE=(train=-0.427, test=-0.851), MSE=(train=-0.340, test=-1.567), R2=(train=0.891, test=0.548), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50, MAE=(train=-0.443, test=-0.764), MSE=(train=-0.376, test=-1.098), R2=(train=0.883, test=0.649), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50, MAE=(train=-0.443, test=-0.702), MSE=(train=-0.380, test=-0.890), R2=(train=0.880, test=0.725), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50, MAE=(train=-0.439, test=-0.753), MSE=(train=-0.365, test=-1.141), R2=(train=0.886, test=0.640), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=50, MAE=(train=-0.438, test=-0.748), MSE=(train=-0.380, test=-0.911), R2=(train=0.884, test=0.681), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80, MAE=(train=-0.426, test=-0.838), MSE=(train=-0.339, test=-1.500), R2=(train=0.891, test=0.567), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80, MAE=(train=-0.448, test=-0.740), MSE=(train=-0.384, test=-1.060), R2=(train=0.880, test=0.661), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80, MAE=(train=-0.435, test=-0.704), MSE=(train=-0.365, test=-0.911), R2=(train=0.885, test=0.719), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80, MAE=(train=-0.438, test=-0.767), MSE=(train=-0.355, test=-1.138), R2=(train=0.889, test=0.641), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=80, MAE=(train=-0.435, test=-0.745), MSE=(train=-0.376, test=-0.909), R2=(train=0.885, test=0.682), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100, MAE=(train=-0.428, test=-0.844), MSE=(train=-0.339, test=-1.529), R2=(train=0.891, test=0.559), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100, MAE=(train=-0.444, test=-0.734), MSE=(train=-0.376, test=-1.061), R2=(train=0.883, test=0.661), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100, MAE=(train=-0.438, test=-0.705), MSE=(train=-0.366, test=-0.900), R2=(train=0.885, test=0.722), total=   0.6s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=100, MAE=(train=-0.441, test=-0.767), MSE=(train=-0.365, test=-1.143), R2=(train=0.886, test=0.640), total=   0.6s
# ...
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180, MAE=(train=-0.420, test=-0.837), MSE=(train=-0.328, test=-1.532), R2=(train=0.895, test=0.558), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180, MAE=(train=-0.436, test=-0.741), MSE=(train=-0.368, test=-1.055), R2=(train=0.885, test=0.663), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180, MAE=(train=-0.439, test=-0.705), MSE=(train=-0.368, test=-0.895), R2=(train=0.884, test=0.724), total=   1.2s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180, MAE=(train=-0.436, test=-0.767), MSE=(train=-0.353, test=-1.133), R2=(train=0.889, test=0.643), total=   1.2s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=10, randomforestregressor__n_estimators=180, MAE=(train=-0.438, test=-0.752), MSE=(train=-0.378, test=-0.906), R2=(train=0.884, test=0.683), total=   1.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50, MAE=(train=-0.453, test=-0.827), MSE=(train=-0.385, test=-1.527), R2=(train=0.877, test=0.559), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50, MAE=(train=-0.479, test=-0.759), MSE=(train=-0.432, test=-1.086), R2=(train=0.865, test=0.653), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50, MAE=(train=-0.472, test=-0.702), MSE=(train=-0.416, test=-0.880), R2=(train=0.869, test=0.728), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50, MAE=(train=-0.472, test=-0.782), MSE=(train=-0.413, test=-1.180), R2=(train=0.871, test=0.628), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=50, MAE=(train=-0.474, test=-0.770), MSE=(train=-0.437, test=-0.952), R2=(train=0.866, test=0.667), total=   0.3s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80, MAE=(train=-0.453, test=-0.835), MSE=(train=-0.377, test=-1.528), R2=(train=0.879, test=0.559), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80, MAE=(train=-0.474, test=-0.737), MSE=(train=-0.434, test=-1.064), R2=(train=0.865, test=0.660), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80, MAE=(train=-0.470, test=-0.711), MSE=(train=-0.418, test=-0.911), R2=(train=0.869, test=0.719), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80, MAE=(train=-0.474, test=-0.776), MSE=(train=-0.419, test=-1.156), R2=(train=0.869, test=0.636), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=80, MAE=(train=-0.465, test=-0.752), MSE=(train=-0.433, test=-0.912), R2=(train=0.867, test=0.681), total=   0.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100, MAE=(train=-0.449, test=-0.841), MSE=(train=-0.371, test=-1.518), R2=(train=0.881, test=0.562), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100, MAE=(train=-0.467, test=-0.759), MSE=(train=-0.418, test=-1.110), R2=(train=0.870, test=0.645), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100, MAE=(train=-0.476, test=-0.703), MSE=(train=-0.429, test=-0.898), R2=(train=0.865, test=0.723), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100, MAE=(train=-0.468, test=-0.773), MSE=(train=-0.397, test=-1.162), R2=(train=0.876, test=0.634), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=100, MAE=(train=-0.465, test=-0.743), MSE=(train=-0.417, test=-0.885), R2=(train=0.872, test=0.690), total=   0.5s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130, MAE=(train=-0.457, test=-0.839), MSE=(train=-0.384, test=-1.524), R2=(train=0.877, test=0.560), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130, MAE=(train=-0.471, test=-0.734), MSE=(train=-0.428, test=-1.061), R2=(train=0.866, test=0.661), total=   0.8s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130, MAE=(train=-0.471, test=-0.703), MSE=(train=-0.424, test=-0.894), R2=(train=0.867, test=0.724), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130, MAE=(train=-0.470, test=-0.768), MSE=(train=-0.404, test=-1.163), R2=(train=0.873, test=0.634), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=130, MAE=(train=-0.463, test=-0.760), MSE=(train=-0.423, test=-0.930), R2=(train=0.870, test=0.674), total=   0.7s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180, MAE=(train=-0.450, test=-0.835), MSE=(train=-0.371, test=-1.527), R2=(train=0.881, test=0.559), total=   1.1s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180, MAE=(train=-0.473, test=-0.737), MSE=(train=-0.422, test=-1.071), R2=(train=0.868, test=0.658), total=   1.1s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180, MAE=(train=-0.472, test=-0.700), MSE=(train=-0.423, test=-0.888), R2=(train=0.867, test=0.726), total=   1.4s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180
# [CV]  randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180, MAE=(train=-0.469, test=-0.768), MSE=(train=-0.404, test=-1.146), R2=(train=0.873, test=0.639), total=   2.0s
# [CV] randomforestregressor__max_depth=60, randomforestregressor__max_features=auto, randomforestregressor__min_samples_leaf=1, randomforestregressor__min_samples_split=12, randomforestregressor__n_estimators=180

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We got the <b>best parameters</b> so, we are going to <b>analyze</b> them more in details
# </div>

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.5.1 Random Forest Validation curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Validation curve</b>, we are going to use a <b>range of neighbors</b> to analyze the model through them
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

n_estimators = np.unique(np.logspace(0, 1.8, num=30).astype(int))

reg = make_pipeline(preprocessor, RandomForestRegressor(bootstrap=False, max_depth=80, max_features="sqrt", min_samples_leaf=3, min_samples_split=8))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the validacion curve</b> based on the best parameters
# </div>

# %%
plot_validation_curve(reg, "RandomForestRegressor", X_train, y_train, param_name="randomforestregressor__n_estimators", param_range=n_estimators, param_name_short="Estimators", cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.5.2 Random Forest Learning curve</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Learning curve</b>, we are going to use the <b>best  parameters</b> to analyze the model
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, RandomForestRegressor(bootstrap=True, max_depth=100, max_features="auto", min_samples_leaf=3, min_samples_split=10, n_estimators=100))

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the learning curve</b> based on the best parameters
# </div>

# %%
plot_learning_curve(reg, "RandomForestRegressor", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.5.3 Random Forest predictions validations</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>predictions validations</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> and <b>predicting</b> values</b>
# </div>

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=0)

reg = make_pipeline(preprocessor, RandomForestRegressor(bootstrap=True, max_depth=100, max_features="auto", min_samples_leaf=3, min_samples_split=10, n_estimators=100))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Cross-Validated Predictions</b> based on the best parameters for <b>training data</b>
# </div>

# %%
# Making the prediction using the testing data
plot_cross_val_predi(reg, "RandomForestRegressor", X_train, y_train, cv=kfold)

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.5.4 Random Forest  Features Importance</h4>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     To plot the <b>Features Importance</b>, we are going to use the <b>best  parameters</b> to analyze the model after <b>fitting</b> values</b>
# </div>

# %%
reg = make_pipeline(preprocessor, RandomForestRegressor(bootstrap=True, max_depth=100, max_features="auto", min_samples_leaf=3, min_samples_split=10, n_estimators=100))

reg.fit(X_train, y_train)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Plotting <b>the Features Importance</b> based on the best parameters
# </div>

# %%
plot_features_importance(reg, "RandomForestRegressor", X_train, y_train, scoring="neg_mean_squared_error")

# %% [markdown]
# <div style="background-color: #6D83C5;" >
#     <h4 style="margin: auto; padding: 20px; color:#fff; ">6.5.6 Concatenating the results to compare</h4>
# </div>

# %%
reg = make_pipeline(preprocessor, RandomForestRegressor(bootstrap=True, max_depth=100, max_features="auto", min_samples_leaf=3, min_samples_split=10, n_estimators=100))

reg.fit(X_train, y_train)

# Making the prediction using the testing data
y_pred = reg.predict(X_test)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding the prediction to compare at the end
# </div>

# %%
# Concatenating predictions to compare against y_test_transformed
df_temp = pd.DataFrame({
    "Model" : "RandomForestRegressor",
    "y_pred" : y_pred
})

# %%
# Concatenating predictions to compare against y_test_transformed
df_y_pred_gsc = pd.concat([df_y_pred_gsc, df_temp])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Adding metrics to compare at the end
# </div>

# %%
# Adding results into LIST
LIST_MODEL_GSC.append("KNeighbors")
LIST_MAE_GSC.append(round(abs(df_results.iloc[search.best_index_]["mean_test_MAE"]), 3))
LIST_RMSE_GSC.append(round(math.sqrt(abs(df_results.iloc[search.best_index_]["mean_test_MSE"])), 3))
LIST_R2SCORE_GSC.append(round(search.best_score_, 3))
LIST_DURATION_GSC.append(round(df_results.iloc[search.best_index_]["mean_score_time"], 3))

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Flag position</b>
# </div>

# %% [markdown]
# - Learning curves
# - metrics R2, MSE, MAE, etc....
# - gráfica comparación de predicción con regresión
#     - arreglar metrica R2 y RMSE
# - importancia de features

# %%
XXXXXXXXX

# %% [markdown]
# import io
# import pandas as pd
# df = pd.read_csv(io.StringIO("""column1 | column2 | column3  |column4  | column5
# A       |    B    |    5     |   4234  |   123
# A       |    B    |    2     |   432   |   3243
# A       |    B    |    10    |   123   |   43
# A       |    B    |    1     |   123   |   45
# A       |    B    |    1     |   124   |   23243
# A       |    B    |    1     |   125   |   234
# A       |    B    |    1     |   126   |   23   """), sep="|").pipe(lambda d: d.rename(columns={c:c.strip() for c in d.columns}))
# - cursos a mirar <br>
# https://openclassrooms.com/fr/courses/6401081-improve-the-performance-of-a-machine-learning-model/6559796-tune-your-hyperparameters <br>
# https://openclassrooms.com/fr/courses/6389626-train-a-supervised-machine-learning-model/6389633-think-through-a-classification-task <br>
# https://lms.fun-mooc.fr/courses/course-v1:inria+41026+session01/courseware/cb3cfcaf0cae4cf7801c4e8d5dab9087/96ae0a5c701c4463a60cb975f75baa07/ <br>
# https://www.youtube.com/watch?v=w_bLGK4Pteo
#
# - grafica de error de training vs error test <br>
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_train_error_vs_test_error.html
#
# - plotting learning curves <br>
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html <br>
# https://scikit-learn.org/stable/modules/learning_curve.html <br>
# https://www.dataquest.io/blog/learning-curves-machine-learning/ <br>
# https://utkuufuk.com/2018/05/04/learning-curves/ <br>
# https://vitalflux.com/validation-curves-explained-python-sklearn-example/
#
# - Validation curve <br>
# https://sdsawtelle.github.io/blog/output/week6-andrew-ng-machine-learning-with-python.html
#
# - Visualizaciones <br>
# https://scikit-learn.org/stable/visualizations.html <br>
# https://medium.datadriveninvestor.com/visualizing-scikit-model-performance-fb26ff16f7c6
#
#
# - lsitado de metricas <br>
# https://scikit-learn.org/stable/modules/model_evaluation.html <br>
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score <br>
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# - Receiver Operating Characteristic (ROC) with cross validation <br>
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc_crossval.html#sphx-glr-auto-examples-model-selection-plot-roc-crossval-py
#
# - Underfitting vs. Overfitting <br>
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_underfitting_overfitting.html#sphx-glr-auto-examples-model-selection-plot-underfitting-overfitting-py
#
# - Plotting Cross-Validated Predictions <br>
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_predict.htmlPlotting
#
# - Bias Variance Trade off <br>
# https://towardsdatascience.com/bias-variance-tradeoff-7ca56ba182a
#
# - SkLearn course <br>
# https://inria.github.io/scikit-learn-mooc/index.html
#
# - Evaluate model
# https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
